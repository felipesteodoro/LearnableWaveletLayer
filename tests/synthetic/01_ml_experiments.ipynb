# %% [markdown]
# # 🤖 Experimentos de Machine Learning Clássico (v2 – Enhanced)
#
# ## Objetivo
# Avaliar modelos de ML clássico com **features enriquecidas** via wavelets (db2):
# - **LinearSVR** (Linear Support Vector Regression)
# - **SGDRegressor** (Stochastic Gradient Descent – epsilon insensitive)
# - **ElasticNet** (L1 + L2 Regularization)
# - **Random Forest**
# - **XGBoost**
# - **LightGBM**
# - **CatBoost**
# - **Stacking Ensemble** (RF + XGB + LGB + CatBoost → Ridge)
#
# ## Melhorias sobre v1
# 1. **Features enriquecidas**: wavelet stats + razões inter-nível + FFT + temporal + coeficientes brutos
# 2. **Otimização via RandomizedSearchCV** (mais rápida que GridSearch)
# 3. **Feature selection**: VarianceThreshold + Mutual Information
# 4. **Paralelização agressiva** (n_jobs = CPU - 2 para estabilidade)
# 5. **Modelos lineares como baseline** + ensemble stacking para teto de desempenho

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import time
import os
import warnings
warnings.filterwarnings('ignore')

# ML
from sklearn.svm import LinearSVR
from sklearn.linear_model import SGDRegressor, ElasticNet, RidgeCV
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit
from sklearn.feature_selection import mutual_info_regression, VarianceThreshold
from sklearn.base import clone
from scipy.stats import randint, uniform, loguniform
from scipy import stats as sp_stats
from joblib import Parallel, delayed
import pywt
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor

# Imports locais
import sys
sys.path.append('.')
from src.evaluation import RegressionEvaluator, ResultsManager
from src.visualization import ExperimentVisualizer
from config.experiment_config import (
    DATA_DIR, RESULTS_DIR, WAVELET_CONFIG
)

# Configuração
plt.style.use('seaborn-v0_8-whitegrid')
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

N_JOBS = max(1, os.cpu_count() - 2)  # CPUs - 2 para estabilidade do S.O.

print(f"✅ Imports realizados com sucesso!")
print(f"   CPUs disponíveis: {os.cpu_count()}, usando N_JOBS={N_JOBS}")
# Out:
# ✅ Imports realizados com sucesso!
#    CPUs disponíveis: 128, usando N_JOBS=126

# %% [markdown]
# ## 1. Carregar Dados

# %%
# Carregar datasets
X_train = np.load(DATA_DIR / "X_train.npy")
y_train = np.load(DATA_DIR / "y_train.npy")
X_val = np.load(DATA_DIR / "X_val.npy")
y_val = np.load(DATA_DIR / "y_val.npy")
X_test = np.load(DATA_DIR / "X_test.npy")
y_test = np.load(DATA_DIR / "y_test.npy")

print(f"📦 Dados Carregados:")
print(f"  Train: X={X_train.shape}, y={y_train.shape}")
print(f"  Val:   X={X_val.shape}, y={y_val.shape}")
print(f"  Test:  X={X_test.shape}, y={y_test.shape}")
# Out:
# 📦 Dados Carregados:
#   Train: X=(34820, 256), y=(34820,)
#   Val:   X=(7462, 256), y=(7462,)
#   Test:  X=(7462, 256), y=(7462,)

# %% [markdown]
# ## 2. Extração de Features Enriquecidas (Wavelet + FFT + Temporal + Coeficientes Brutos)

# %%
# ============================================================
# Enhanced Feature Extraction
# ============================================================
WAVELET = WAVELET_CONFIG['wavelet_type']
LEVEL  = WAVELET_CONFIG['decomposition_level']
MODE   = WAVELET_CONFIG['mode']

def extract_enhanced_features_single(x):
    """
    Features enriquecidas de um único sinal:
      1) 12 stats × (level+1) sub-bandas wavelet
      2) Razões de energia inter-nível
      3) 7 features espectrais (FFT)
      4) 6 features temporais (autocorr + trend)
      5) Coeficientes wavelet brutos concatenados
    """
    x = np.asarray(x, dtype=np.float64).squeeze()
    feats = []

    # ---- 1) Wavelet stats por sub-banda ----
    coeffs = pywt.wavedec(x, WAVELET, mode=MODE, level=LEVEL)
    for c in coeffs:
        feats.extend([
            np.mean(c), np.std(c), np.var(c),
            np.max(c), np.min(c), np.ptp(c),
            np.median(c),
            np.sum(c ** 2),                               # energy
            float(sp_stats.skew(c)),
            float(sp_stats.kurtosis(c)),
            np.sqrt(np.mean(c ** 2)),                     # RMS
            np.percentile(c, 75) - np.percentile(c, 25),  # IQR
        ])

    # ---- 2) Razões de energia inter-nível ----
    energies = [np.sum(c ** 2) for c in coeffs]
    total_energy = sum(energies) + 1e-10
    for e in energies:
        feats.append(e / total_energy)
    for i in range(1, len(coeffs)):
        for j in range(i + 1, len(coeffs)):
            feats.append(energies[i] / (energies[j] + 1e-10))

    # ---- 3) Features FFT ----
    fft_vals = np.abs(np.fft.rfft(x))
    freqs = np.fft.rfftfreq(len(x))
    fft_en = fft_vals ** 2
    total_fft = np.sum(fft_en) + 1e-10
    sc = np.sum(freqs * fft_en) / total_fft                          # centroid
    sb = np.sqrt(np.sum((freqs - sc) ** 2 * fft_en) / total_fft)     # bandwidth
    pf = freqs[np.argmax(fft_en)]                                     # peak freq
    cum = np.cumsum(fft_en)
    ro_idx = np.searchsorted(cum, 0.85 * total_fft)
    sr = freqs[min(ro_idx, len(freqs) - 1)]                          # rolloff 85%
    feats.extend([sc, sb, pf, sr, np.max(fft_vals), np.mean(fft_vals), np.std(fft_vals)])

    # ---- 4) Features temporais ----
    for lag in [1, 5, 10, 25, 50]:
        if lag < len(x):
            feats.append(float(np.corrcoef(x[:-lag], x[lag:])[0, 1]))
        else:
            feats.append(0.0)
    feats.append(float(np.polyfit(np.arange(len(x)), x, 1)[0]))  # slope

    # ---- 5) Coeficientes wavelet brutos ----
    feats.extend(np.concatenate(coeffs).tolist())

    return np.array(feats, dtype=np.float32)


def extract_enhanced_features(X, n_jobs=N_JOBS):
    """Extrai features em paralelo (joblib threads)."""
    results = Parallel(n_jobs=n_jobs, prefer='threads', verbose=0)(
        delayed(extract_enhanced_features_single)(X[i]) for i in range(len(X))
    )
    return np.vstack(results)


def get_feature_names(sample_len=256):
    """Gera nomes das features (mesma ordem de extract_enhanced_features_single)."""
    names = []
    sub_bands = [f'A{LEVEL}'] + [f'D{LEVEL - i}' for i in range(LEVEL)]
    stat_names = ['mean', 'std', 'var', 'max', 'min', 'ptp', 'median',
                  'energy', 'skew', 'kurtosis', 'rms', 'iqr']
    for sb in sub_bands:
        for s in stat_names:
            names.append(f'{sb}_{s}')
    for sb in sub_bands:
        names.append(f'eratio_{sb}')
    for i in range(1, len(sub_bands)):
        for j in range(i + 1, len(sub_bands)):
            names.append(f'eratio_{sub_bands[i]}_{sub_bands[j]}')
    for f in ['centroid', 'bandwidth', 'peak_freq', 'rolloff', 'max', 'mean', 'std']:
        names.append(f'fft_{f}')
    for lag in [1, 5, 10, 25, 50]:
        names.append(f'autocorr_{lag}')
    names.append('trend_slope')
    dummy = pywt.wavedec(np.zeros(sample_len), WAVELET, mode=MODE, level=LEVEL)
    n_raw = sum(len(c) for c in dummy)
    for i in range(n_raw):
        names.append(f'raw_coeff_{i}')
    return names


# ---- Executar extração ----
print(f"🔧 Config Wavelet: {WAVELET}, level={LEVEL}, mode={MODE}")
print(f"   Paralelização: {N_JOBS} threads\n")

t0 = time.time()
print("Extraindo features TRAIN...")
X_train_feat = extract_enhanced_features(X_train)
print("Extraindo features VAL...")
X_val_feat = extract_enhanced_features(X_val)
print("Extraindo features TEST...")
X_test_feat = extract_enhanced_features(X_test)

elapsed_feat = time.time() - t0
n_sub = LEVEL + 1
n_stat = n_sub * 12
n_ratio = n_sub + LEVEL * (LEVEL - 1) // 2
n_raw = X_train_feat.shape[1] - n_stat - n_ratio - 7 - 6
print(f"\n⏱️  Tempo de extração: {elapsed_feat:.1f}s")
print(f"\n📊 Features Enriquecidas: {X_train_feat.shape[1]} por amostra")
print(f"    Wavelet stats:       {n_stat}")
print(f"    Energy ratios:       {n_ratio}")
print(f"    FFT features:        7")
print(f"    Temporal features:   6")
print(f"    Raw coefficients:    {n_raw}")
print(f"\n  Train: {X_train_feat.shape}")
print(f"  Val:   {X_val_feat.shape}")
print(f"  Test:  {X_test_feat.shape}")
# Out:
# 🔧 Config Wavelet: db2, level=4, mode=symmetric
#    Paralelização: 126 threads
#
# Extraindo features TRAIN...

# %%
# ============================================================
# Normalização + Feature Selection leve
# ============================================================

# Remover features com variância nula
vt = VarianceThreshold(threshold=1e-8)
X_train_vt = vt.fit_transform(X_train_feat)
X_val_vt = vt.transform(X_val_feat)
X_test_vt = vt.transform(X_test_feat)
n_removed = X_train_feat.shape[1] - X_train_vt.shape[1]
print(f"VarianceThreshold: {X_train_vt.shape[1]} features mantidas ({n_removed} removidas)")

# Normalização
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_vt)
X_val_scaled = scaler.transform(X_val_vt)
X_test_scaled = scaler.transform(X_test_vt)

# Safety: remover NaN/Inf
X_train_scaled = np.nan_to_num(X_train_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_val_scaled = np.nan_to_num(X_val_scaled, nan=0.0, posinf=0.0, neginf=0.0)
X_test_scaled = np.nan_to_num(X_test_scaled, nan=0.0, posinf=0.0, neginf=0.0)

# Combinar train + val para busca de hiperparâmetros
X_trainval = np.vstack([X_train_scaled, X_val_scaled])
y_trainval = np.concatenate([y_train, y_val])

# Mutual Information para análise
print("\n🔍 Calculando Mutual Information (top 15)...")
mi_scores = mutual_info_regression(
    X_train_scaled[:5000], y_train[:5000],  # sub-amostra para velocidade
    n_neighbors=5, random_state=42
)
feature_names_all = get_feature_names()
kept_mask = vt.get_support()
feature_names_filtered = [feature_names_all[i] for i, k in enumerate(kept_mask) if k]
top_mi_idx = np.argsort(mi_scores)[::-1][:15]
print("  Top 15 features por MI:")
for rank, idx in enumerate(top_mi_idx, 1):
    name = feature_names_filtered[idx] if idx < len(feature_names_filtered) else f'feat_{idx}'
    print(f"    {rank:2d}. {name:30s} MI={mi_scores[idx]:.4f}")

print(f"\n✅ Features prontas")
print(f"  TrainVal combinado: {X_trainval.shape}")
# Out:
# ✅ Features normalizadas
#   TrainVal combinado: (42282, 85)

# %% [markdown]
# ## 3. Configuração de Experimentos

# %%
# Gerenciador de resultados
results_manager = ResultsManager(RESULTS_DIR / "ml_experiments")
evaluator = RegressionEvaluator()

# Armazenar todos os resultados
all_results = {}

# TimeSeriesSplit para validação cruzada
tscv = TimeSeriesSplit(n_splits=5)

# ---- Helper para rodar e registrar um experimento ----
def run_experiment(name, model, X_tv, y_tv, X_te, y_te,
                   param_dist=None, n_iter=40,
                   category='ML_FixedWavelet'):
    """Roda RandomizedSearchCV (ou fit direto) e retorna o melhor modelo."""
    print(f"\n{'='*60}")
    print(f"  {name}")
    print(f"{'='*60}")
    t0 = time.time()

    if param_dist:
        search = RandomizedSearchCV(
            model, param_dist, n_iter=n_iter, cv=tscv,
            scoring='neg_mean_squared_error',
            n_jobs=N_JOBS, verbose=1, random_state=42
        )
        search.fit(X_tv, y_tv)
        best = search.best_estimator_
        best_params = search.best_params_
        print(f"  Melhores parâmetros: {best_params}")
    else:
        model.fit(X_tv, y_tv)
        best = model
        best_params = model.get_params()

    y_pred = best.predict(X_te)
    metrics = evaluator.evaluate(y_te, y_pred)
    elapsed = time.time() - t0

    print(f"\n  📊 {name}:")
    print(f"     RMSE: {metrics['rmse']:.6f}")
    print(f"     MAE:  {metrics['mae']:.6f}")
    print(f"     R²:   {metrics['r2']:.6f}")
    print(f"     Tempo: {elapsed:.1f}s")

    all_results[name] = {
        'metrics': metrics,
        'best_params': best_params,
        'time': elapsed,
        'y_pred': y_pred,
        'model': best,
    }
    results_manager.log_experiment(category, name, metrics, {'params': str(best_params)})
    return best

print(f"✅ Configuração pronta – RandomizedSearchCV com TimeSeriesSplit(5)")
print(f"   Paralelização: n_jobs={N_JOBS}")

# %% [markdown]
# ## 4. Experimento 1: LinearSVR

# %%
best_linearsvr = run_experiment(
    'Wavelet_LinearSVR',
    LinearSVR(max_iter=10000, random_state=42),
    X_trainval, y_trainval, X_test_scaled, y_test,
    param_dist={
        'C': loguniform(1e-2, 1e3),
        'epsilon': uniform(0.0, 0.5),
        'loss': ['epsilon_insensitive', 'squared_epsilon_insensitive'],
    },
    n_iter=60,
)
# Out:
# ============================================================
# 🔵 Experimento: SVM com Features Wavelet
# ============================================================
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Melhores parâmetros: {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
#
# 📊 Resultados SVM:
#   RMSE: 1.103630
#   MAE:  0.892672
#   R²:   -0.205247
#   Tempo: 19553.19s
# 'ML_Wavelet_SVM_2026-02-16T03-48-48.866675'

# %% [markdown]
# ## 5. Experimento 2: SGDRegressor (epsilon-insensitive)

# %%
best_sgd = run_experiment(
    'Wavelet_SGD',
    SGDRegressor(random_state=42, max_iter=2000),
    X_trainval, y_trainval, X_test_scaled, y_test,
    param_dist={
        'loss': ['epsilon_insensitive', 'squared_epsilon_insensitive', 'huber'],
        'alpha': loguniform(1e-6, 1e-1),
        'epsilon': uniform(0.01, 0.5),
        'penalty': ['l2', 'l1', 'elasticnet'],
        'l1_ratio': uniform(0.0, 1.0),
        'learning_rate': ['optimal', 'invscaling', 'adaptive'],
    },
    n_iter=80,
)
# Out:
# ============================================================
# 🌲 Experimento: Random Forest com Features Wavelet
# ============================================================
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
#
# Melhores parâmetros: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
#
# 📊 Resultados Random Forest:
#   RMSE: 0.890136
#   MAE:  0.672465
#   R²:   0.215955
#   Tempo: 341.31s
# 'ML_Wavelet_RandomForest_2026-02-16T03-54-30.314002'

# %% [markdown]
# ## 6. Experimento 3: ElasticNet

# %%
best_elasticnet = run_experiment(
    'Wavelet_ElasticNet',
    ElasticNet(max_iter=5000, random_state=42),
    X_trainval, y_trainval, X_test_scaled, y_test,
    param_dist={
        'alpha': loguniform(1e-5, 10.0),
        'l1_ratio': uniform(0.0, 1.0),
    },
    n_iter=60,
)
# Out:
# ============================================================
# 🚀 Experimento: XGBoost com Features Wavelet
# ============================================================
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
#
# Melhores parâmetros: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8}
#
# 📊 Resultados XGBoost:
#   RMSE: 0.877987
#   MAE:  0.663882
#   R²:   0.237210
#   Tempo: 110.65s
# 'ML_Wavelet_XGBoost_2026-02-16T03-56-20.990890'

# %% [markdown]
# ## 7. Experimento 4: Random Forest

# %%
best_rf = run_experiment(
    'Wavelet_RF',
    RandomForestRegressor(random_state=42, n_jobs=1),
    X_trainval, y_trainval, X_test_scaled, y_test,
    param_dist={
        'n_estimators': randint(100, 500),
        'max_depth': [10, 20, 30, 50, None],
        'min_samples_split': randint(2, 20),
        'min_samples_leaf': randint(1, 10),
        'max_features': ['sqrt', 'log2', 0.5, 0.8, None],
    },
    n_iter=50,
)
# Out:
# ============================================================
# 💡 Experimento: LightGBM com Features Wavelet
# ============================================================
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
#
# Melhores parâmetros: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 50}
#
# 📊 Resultados LightGBM:
#   RMSE: 0.877101
#   MAE:  0.662678
#   R²:   0.238749
#   Tempo: 27982.29s
# 'ML_Wavelet_LightGBM_2026-02-16T11-42-43.309981'

# %% [markdown]
# ## 8. Experimento 5: XGBoost

# %%
best_xgb = run_experiment(
    'Wavelet_XGB',
    xgb.XGBRegressor(random_state=42, n_jobs=1, verbosity=0, tree_method='hist'),
    X_trainval, y_trainval, X_test_scaled, y_test,
    param_dist={
        'n_estimators': randint(100, 500),
        'max_depth': randint(3, 12),
        'learning_rate': loguniform(0.01, 0.3),
        'subsample': uniform(0.6, 0.4),
        'colsample_bytree': uniform(0.5, 0.5),
        'reg_alpha': loguniform(1e-4, 10.0),
        'reg_lambda': loguniform(1e-4, 10.0),
        'min_child_weight': randint(1, 10),
    },
    n_iter=60,
)

# %% [markdown]
# ## 9. Experimento 6: LightGBM

# %%
best_lgb = run_experiment(
    'Wavelet_LGBM',
    lgb.LGBMRegressor(random_state=42, n_jobs=1, verbose=-1),
    X_trainval, y_trainval, X_test_scaled, y_test,
    param_dist={
        'n_estimators': randint(100, 500),
        'max_depth': randint(3, 15),
        'learning_rate': loguniform(0.01, 0.3),
        'num_leaves': randint(20, 150),
        'subsample': uniform(0.6, 0.4),
        'colsample_bytree': uniform(0.5, 0.5),
        'reg_alpha': loguniform(1e-4, 10.0),
        'reg_lambda': loguniform(1e-4, 10.0),
        'min_child_samples': randint(5, 50),
    },
    n_iter=60,
)

# %% [markdown]
# ## 10. Experimento 7: CatBoost

# %%
best_catboost = run_experiment(
    'Wavelet_CatBoost',
    CatBoostRegressor(random_seed=42, verbose=0, thread_count=1),
    X_trainval, y_trainval, X_test_scaled, y_test,
    param_dist={
        'iterations': randint(200, 600),
        'depth': randint(4, 10),
        'learning_rate': loguniform(0.01, 0.3),
        'l2_leaf_reg': loguniform(1e-2, 10.0),
        'bagging_temperature': uniform(0.0, 1.0),
        'random_strength': uniform(0.0, 2.0),
    },
    n_iter=40,
)

# %% [markdown]
# ## 11. Experimento 8: Stacking Ensemble

# %%
# Stacking ensemble: RF + XGB + LGB + CatBoost → Ridge meta-learner
print("\n" + "=" * 60)
print("  🔗 Wavelet_Stacking (RF + XGB + LGB + CatBoost → Ridge)")
print("=" * 60)

t0 = time.time()

# Reconstruir base estimators com n_jobs para stacking
def _set_parallel(est, n):
    est = clone(est)
    if hasattr(est, 'n_jobs'):
        est.set_params(n_jobs=n)
    if hasattr(est, 'thread_count'):
        est.set_params(thread_count=n)
    return est

stacking = StackingRegressor(
    estimators=[
        ('rf',       _set_parallel(all_results['Wavelet_RF']['model'], N_JOBS)),
        ('xgb',      _set_parallel(all_results['Wavelet_XGB']['model'], N_JOBS)),
        ('lgb',      _set_parallel(all_results['Wavelet_LGBM']['model'], N_JOBS)),
        ('catboost', _set_parallel(all_results['Wavelet_CatBoost']['model'], N_JOBS)),
    ],
    final_estimator=RidgeCV(alphas=[0.01, 0.1, 1.0, 10.0, 100.0]),
    cv=tscv,
    n_jobs=1,  # sequencial: cada base model já usa N_JOBS interno
)
stacking.fit(X_trainval, y_trainval)

y_pred_stack = stacking.predict(X_test_scaled)
stack_metrics = evaluator.evaluate(y_test, y_pred_stack)
elapsed = time.time() - t0

print(f"\n  📊 Wavelet_Stacking:")
print(f"     RMSE: {stack_metrics['rmse']:.6f}")
print(f"     MAE:  {stack_metrics['mae']:.6f}")
print(f"     R²:   {stack_metrics['r2']:.6f}")
print(f"     Tempo: {elapsed:.1f}s")

all_results['Wavelet_Stacking'] = {
    'metrics': stack_metrics,
    'best_params': {'meta': 'RidgeCV', 'base': ['RF', 'XGB', 'LGB', 'CatBoost']},
    'time': elapsed,
    'y_pred': y_pred_stack,
    'model': stacking,
}
results_manager.log_experiment('ML_FixedWavelet', 'Stacking', stack_metrics,
                               {'base': 'RF+XGB+LGB+CatBoost', 'meta': 'RidgeCV'})

# %% [markdown]
# ## 12. Comparação dos Resultados

# %%
# Criar DataFrame comparativo
comparison_data = []
for model_name, result in all_results.items():
    row = {
        'Model': model_name,
        'RMSE': result['metrics']['rmse'],
        'MAE': result['metrics']['mae'],
        'R²': result['metrics']['r2'],
        'Time (s)': result['time']
    }
    comparison_data.append(row)

comparison_df = pd.DataFrame(comparison_data)
comparison_df = comparison_df.sort_values('RMSE')

print("\n" + "=" * 80)
print("📊 COMPARAÇÃO FINAL - ML com Features Wavelet Enriquecidas (db2)")
print("=" * 80)
print(comparison_df.to_string(index=False))

# Salvar
comparison_df.to_csv(RESULTS_DIR / "ml_experiments" / "comparison_ml.csv", index=False)
print(f"\n✅ CSV salvo em: {RESULTS_DIR / 'ml_experiments' / 'comparison_ml.csv'}")
# Out:
# ======================================================================
# 📊 COMPARAÇÃO FINAL - ML com Features Wavelet (db2)
# ======================================================================
#        Model     RMSE      MAE        R²     Time (s)
# Wavelet_LGBM 0.877101 0.662678  0.238749 27982.288899
#  Wavelet_XGB 0.877987 0.663882  0.237210   110.651484
#   Wavelet_RF 0.890136 0.672465  0.215955   341.313228
#  Wavelet_SVM 1.103630 0.892672 -0.205247 19553.194274

# %%
# Visualização comparativa
fig, axes = plt.subplots(1, 3, figsize=(20, 7))

model_colors = {
    'Wavelet_LinearSVR': '#4e79a7', 'Wavelet_SGD': '#59a14f',
    'Wavelet_ElasticNet': '#76b7b2', 'Wavelet_RF': '#f28e2b',
    'Wavelet_XGB': '#e15759', 'Wavelet_LGBM': '#edc948',
    'Wavelet_CatBoost': '#b07aa1', 'Wavelet_Stacking': '#ff9da7',
}

metrics_to_plot = ['RMSE', 'MAE', 'R²']
for idx, metric in enumerate(metrics_to_plot):
    data = comparison_df.set_index('Model')[metric].sort_values(
        ascending=(metric != 'R²')
    )
    colors = [model_colors.get(m, '#999999') for m in data.index]
    bars = axes[idx].barh(data.index, data.values, color=colors)
    axes[idx].set_xlabel(metric)
    axes[idx].set_title(f'Comparação: {metric}')
    axes[idx].grid(True, alpha=0.3, axis='x')
    for bar, val in zip(bars, data.values):
        axes[idx].text(val, bar.get_y() + bar.get_height()/2,
                      f'{val:.4f}', va='center', ha='left', fontsize=8)

plt.suptitle('ML Clássico com Features Wavelet Enriquecidas (db2)',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(RESULTS_DIR / "ml_experiments" / "comparison_ml.png", dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 13. Análise de Predições do Melhor Modelo

# %%
# Encontrar melhor modelo
best_model_name = comparison_df.iloc[0]['Model']
best_result = all_results[best_model_name]

print(f"\n🏆 Melhor Modelo: {best_model_name}")
print(f"   RMSE={best_result['metrics']['rmse']:.6f}, R²={best_result['metrics']['r2']:.6f}")

# Plot de predições
visualizer = ExperimentVisualizer()
fig = visualizer.plot_prediction_comparison(
    y_test, best_result['y_pred'],
    model_name=best_model_name,
    n_samples=500,
    save_path=RESULTS_DIR / "ml_experiments" / f"predictions_{best_model_name}.png"
)
plt.show()
# Out:
# 🏆 Melhor Modelo: Wavelet_LGBM

# %% [markdown]
# ## 14. Feature Importance (modelos baseados em árvore)

# %%
# Feature importance – 4 modelos baseados em árvore
fig, axes = plt.subplots(2, 2, figsize=(22, 16))

tree_models = [
    ('Random Forest', all_results['Wavelet_RF']['model']),
    ('XGBoost', all_results['Wavelet_XGB']['model']),
    ('LightGBM', all_results['Wavelet_LGBM']['model']),
    ('CatBoost', all_results['Wavelet_CatBoost']['model']),
]

for ax, (title, model) in zip(axes.flat, tree_models):
    imp = model.feature_importances_
    top_idx = np.argsort(imp)[::-1][:25]
    names = [feature_names_filtered[i] if i < len(feature_names_filtered)
             else f'feat_{i}' for i in top_idx]
    ax.barh(range(len(top_idx)), imp[top_idx], color='steelblue', alpha=0.8)
    ax.set_yticks(range(len(top_idx)))
    ax.set_yticklabels(names, fontsize=7)
    ax.set_title(f'{title} – Top 25 Features')
    ax.invert_yaxis()

plt.suptitle('Importância das Features Enriquecidas (Wavelet + FFT + Temporal + Raw Coefs)',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(RESULTS_DIR / "ml_experiments" / "feature_importance.png", dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 15. Resumo

# %%
print("\n" + "=" * 80)
print("📋 RESUMO – Experimentos ML com Features Wavelet Enriquecidas")
print("=" * 80)
print(f"\n✅ Modelos avaliados: {len(all_results)}")
print(f"✅ Melhor modelo: {best_model_name}")
print(f"✅ Melhor RMSE: {comparison_df.iloc[0]['RMSE']:.6f}")
print(f"✅ Melhor R²:   {comparison_df.iloc[0]['R²']:.6f}")
print(f"\n📊 Features: {X_trainval.shape[1]} "
      f"(wavelet stats + razões inter-nível + FFT + temporal + raw coefs)")
print(f"📁 Resultados salvos em: {RESULTS_DIR / 'ml_experiments'}")
print("\n🎉 Notebook concluído com sucesso!")
# Out:
# ======================================================================
# 📋 RESUMO - Experimentos ML com Features Wavelet
# ======================================================================
#
# ✅ Modelos avaliados: 4
# ✅ Melhor modelo: Wavelet_LGBM
# ✅ Melhor RMSE: 0.877101
# ✅ Melhor R²: 0.238749
#
# 📁 Resultados salvos em: /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/ml_experiments
#
# 🎉 Notebook concluído com sucesso!
