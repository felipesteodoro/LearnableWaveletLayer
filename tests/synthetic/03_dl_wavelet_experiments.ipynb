# %% [markdown]
# # 🌊 Experimentos Deep Learning - Wavelets Fixas (db2)
#
# ## Objetivo
# Avaliar modelos de Deep Learning usando coeficientes wavelet fixos (db2) como pré-processamento:
# - **CNN + Wavelet db2**
# - **LSTM + Wavelet db2**
# - **CNN-LSTM + Wavelet db2**
# - **Transformer + Wavelet db2**
#
# ## Pipeline
# 1. Carregar dados
# 2. Extrair coeficientes wavelet multi-nível (como canais)
# 3. Treinar cada modelo
# 4. Comparar com resultados do sinal raw

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')

# TensorFlow
import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")
print(f"GPU disponível: {tf.config.list_physical_devices('GPU')}")

# Imports locais
import sys
sys.path.append('.')
from src.models import (
    create_cnn_model, create_lstm_model, 
    create_cnn_lstm_model, create_transformer_model,
    get_callbacks
)
from src.feature_extraction import WaveletFeatureExtractor
from src.evaluation import RegressionEvaluator, ResultsManager
from src.visualization import ExperimentVisualizer
from config.experiment_config import (
    DATA_DIR, RESULTS_DIR, MODELS_DIR,
    DL_TRAINING_CONFIG, DL_MODELS_CONFIG, WAVELET_CONFIG
)

# Configuração
plt.style.use('seaborn-v0_8-whitegrid')
(RESULTS_DIR / "dl_wavelet_experiments").mkdir(parents=True, exist_ok=True)

print("\n✅ Imports realizados com sucesso!")
# Out:
# 2026-02-16 13:42:51.275559: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.20.0
# GPU disponível: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
#
# ✅ Imports realizados com sucesso!

# %% [markdown]
# ## 1. Carregar e Transformar Dados

# %%
# Carregar datasets (raw)
X_train_raw = np.load(DATA_DIR / "X_train.npy")
y_train = np.load(DATA_DIR / "y_train.npy")
X_val_raw = np.load(DATA_DIR / "X_val.npy")
y_val = np.load(DATA_DIR / "y_val.npy")
X_test_raw = np.load(DATA_DIR / "X_test.npy")
y_test = np.load(DATA_DIR / "y_test.npy")

print(f"📦 Dados Carregados (Raw):")
print(f"  Train: {X_train_raw.shape}")
print(f"  Val:   {X_val_raw.shape}")
print(f"  Test:  {X_test_raw.shape}")
# Out:
# 📦 Dados Carregados (Raw):
#   Train: (34820, 256)
#   Val:   (7462, 256)
#   Test:  (7462, 256)

# %%
# Configurar extrator de wavelet
wavelet_extractor = WaveletFeatureExtractor(
    wavelet=WAVELET_CONFIG['wavelet_type'],
    level=WAVELET_CONFIG['decomposition_level'],
    mode=WAVELET_CONFIG['mode']
)

print(f"Extrator Wavelet:")
print(f"  Wavelet: {WAVELET_CONFIG['wavelet_type']}")
print(f"  Níveis: {WAVELET_CONFIG['decomposition_level']}")

# Transformar para coeficientes multi-nível (como canais)
print("\nTransformando sinais para coeficientes wavelet...")
t0 = time.time()

X_train = wavelet_extractor.get_multilevel_coefficients(X_train_raw, align_length=True)
X_val = wavelet_extractor.get_multilevel_coefficients(X_val_raw, align_length=True)
X_test = wavelet_extractor.get_multilevel_coefficients(X_test_raw, align_length=True)

print(f"  Tempo: {time.time()-t0:.2f}s")

print(f"\n📊 Dados Transformados (Wavelet Coefficients):")
print(f"  Train: {X_train.shape}  [samples, length, channels=níveis+1]")
print(f"  Val:   {X_val.shape}")
print(f"  Test:  {X_test.shape}")
print(f"\n  Canais: [Approx, Detail_1, Detail_2, Detail_3, Detail_4]")

input_shape = X_train.shape[1:]
print(f"\nInput shape para modelos: {input_shape}")
# Out:
# Extrator Wavelet:
#   Wavelet: db2
#   Níveis: 4
#
# Transformando sinais para coeficientes wavelet...
#   Tempo: 19.34s
#
# 📊 Dados Transformados (Wavelet Coefficients):
#   Train: (34820, 129, 5)  [samples, length, channels=níveis+1]
#   Val:   (7462, 129, 5)
#   Test:  (7462, 129, 5)
#
#   Canais: [Approx, Detail_1, Detail_2, Detail_3, Detail_4]
#
# Input shape para modelos: (129, 5)

# %% [markdown]
# ## 2. Visualização dos Coeficientes Wavelet

# %%
# Visualizar uma amostra transformada
sample_idx = 1000

fig, axes = plt.subplots(2, 3, figsize=(15, 8))

# Sinal original
axes[0, 0].plot(X_train_raw[sample_idx], alpha=0.7)
axes[0, 0].set_title('Sinal Original (Raw)')
axes[0, 0].grid(True, alpha=0.3)

# Coeficientes wavelet
channel_names = ['Approx (A4)', 'Detail 1 (D1)', 'Detail 2 (D2)', 
                 'Detail 3 (D3)', 'Detail 4 (D4)']
for i, (ax, name) in enumerate(zip(axes.flatten()[1:], channel_names)):
    ax.plot(X_train[sample_idx, :, i], alpha=0.7)
    ax.set_title(f'Canal {i}: {name}')
    ax.grid(True, alpha=0.3)

plt.suptitle(f'Transformação Wavelet (db2) - Amostra {sample_idx}', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(RESULTS_DIR / "dl_wavelet_experiments" / "wavelet_transformation_sample.png", dpi=150)
plt.show()

# %% [markdown]
# ## 3. Configuração

# %%
# Gerenciadores
results_manager = ResultsManager(RESULTS_DIR / "dl_wavelet_experiments")
evaluator = RegressionEvaluator()
visualizer = ExperimentVisualizer()

training_config = DL_TRAINING_CONFIG.copy()

# Armazenar resultados
all_results = {}
all_histories = {}

# %% [markdown]
# ## 4. Experimento 1: CNN + Wavelet

# %%
print("="*70)
print("🔵 Experimento: CNN com Wavelet db2")
print("="*70)

tf.keras.backend.clear_session()

# Criar modelo
cnn_params = DL_MODELS_CONFIG['CNN']
model_cnn = create_cnn_model(input_shape, params=cnn_params)
model_cnn.summary()

# Callbacks
model_path = str(MODELS_DIR / "wavelet_cnn_best.keras")
callbacks = get_callbacks(model_path, patience_early=15, patience_lr=7)

# Treinar
t0 = time.time()
history_cnn = model_cnn.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=training_config['epochs'],
    batch_size=training_config['batch_size'],
    callbacks=callbacks,
    verbose=1
)
elapsed = time.time() - t0

# Predições
y_pred_cnn = model_cnn.predict(X_test, verbose=0).flatten()

# Métricas
cnn_metrics = evaluator.evaluate(y_test, y_pred_cnn)

print(f"\n📊 Resultados CNN (Wavelet db2):")
print(f"  RMSE: {cnn_metrics['rmse']:.6f}")
print(f"  MAE:  {cnn_metrics['mae']:.6f}")
print(f"  R²:   {cnn_metrics['r2']:.6f}")
print(f"  Tempo: {elapsed:.2f}s")

all_results['Wavelet_CNN'] = {
    'metrics': cnn_metrics,
    'time': elapsed,
    'epochs': len(history_cnn.history['loss']),
    'y_pred': y_pred_cnn,
    'params': model_cnn.count_params()
}
all_histories['Wavelet_CNN'] = history_cnn.history

results_manager.log_experiment(
    'DL_Wavelet', 'CNN', cnn_metrics,
    {'params': cnn_params, 'wavelet': WAVELET_CONFIG}
)
# Out:
# ======================================================================
# 🔵 Experimento: CNN com Wavelet db2
# ======================================================================
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771260197.626601 2707491 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14163 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9
# I0000 00:00:1771260197.629617 2707491 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14160 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:4c:00.0, compute capability: 8.9
# Model: "CNN_Regressor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 129, 5)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_1 (Conv1D)                 │ (None, 129, 64)        │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 129, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_2 (Conv1D)                 │ (None, 64, 128)        │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_3 (Conv1D)                 │ (None, 32, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 16, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 184,961 (722.50 KB)
#  Trainable params: 184,065 (719.00 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/100
# 2026-02-16 13:43:23.010832: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f0114009b20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-16 13:43:23.010934: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2026-02-16 13:43:23.010939: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (1): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2026-02-16 13:43:23.146187: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-16 13:43:23.671250: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91900
# 2026-02-16 13:43:24.218819: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:24.218890: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:24.218924: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:24.218957: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:24.218993: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:24.219018: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:27.378099: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3122', 580 bytes spill stores, 580 bytes spill loads
#
# 2026-02-16 13:43:27.762096: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3531', 48 bytes spill stores, 48 bytes spill loads
#
# 2026-02-16 13:43:27.829993: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3547', 48 bytes spill stores, 48 bytes spill loads
#  47/545 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6125 - mae: 0.8112
# I0000 00:00:1771260215.679409 2712561 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0607 - mae: 0.5619
# 2026-02-16 13:43:45.852017: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:46.742018: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_205', 116 bytes spill stores, 116 bytes spill loads
#
# 2026-02-16 13:43:48.315179: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:48.315250: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:43:49.260059: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_198', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-02-16 13:43:49.587141: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_205', 292 bytes spill stores, 292 bytes spill loads
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 32s 29ms/step - loss: 0.7723 - mae: 0.4220 - val_loss: 0.4892 - val_mae: 0.2975 - learning_rate: 0.0010
# Epoch 2/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4031 - mae: 0.2891 - val_loss: 0.3697 - val_mae: 0.3251 - learning_rate: 0.0010
# Epoch 3/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2656 - mae: 0.2682 - val_loss: 0.2592 - val_mae: 0.3041 - learning_rate: 0.0010
# Epoch 4/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2011 - mae: 0.2605 - val_loss: 0.2239 - val_mae: 0.2868 - learning_rate: 0.0010
# Epoch 5/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1756 - mae: 0.2580 - val_loss: 0.1905 - val_mae: 0.2850 - learning_rate: 0.0010
# Epoch 6/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1599 - mae: 0.2520 - val_loss: 0.1629 - val_mae: 0.2641 - learning_rate: 0.0010
# Epoch 7/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1518 - mae: 0.2498 - val_loss: 0.1723 - val_mae: 0.2739 - learning_rate: 0.0010
# Epoch 8/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1487 - mae: 0.2484 - val_loss: 0.1474 - val_mae: 0.2485 - learning_rate: 0.0010
# Epoch 9/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1448 - mae: 0.2433 - val_loss: 0.1677 - val_mae: 0.2830 - learning_rate: 0.0010
# Epoch 10/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1445 - mae: 0.2447 - val_loss: 0.1434 - val_mae: 0.2487 - learning_rate: 0.0010
# Epoch 11/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1422 - mae: 0.2426 - val_loss: 0.1678 - val_mae: 0.2593 - learning_rate: 0.0010
# Epoch 12/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1444 - mae: 0.2428 - val_loss: 0.1639 - val_mae: 0.2723 - learning_rate: 0.0010
# Epoch 13/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1371 - mae: 0.2389 - val_loss: 0.1351 - val_mae: 0.2424 - learning_rate: 0.0010
# Epoch 14/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1467 - mae: 0.2419 - val_loss: 0.1505 - val_mae: 0.2497 - learning_rate: 0.0010
# Epoch 15/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1381 - mae: 0.2388 - val_loss: 0.1492 - val_mae: 0.2514 - learning_rate: 0.0010
# Epoch 16/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1378 - mae: 0.2381 - val_loss: 0.1428 - val_mae: 0.2507 - learning_rate: 0.0010
# Epoch 17/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1348 - mae: 0.2378 - val_loss: 0.1321 - val_mae: 0.2346 - learning_rate: 0.0010
# Epoch 18/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1431 - mae: 0.2395 - val_loss: 0.1976 - val_mae: 0.3047 - learning_rate: 0.0010
# Epoch 19/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1343 - mae: 0.2373 - val_loss: 0.1393 - val_mae: 0.2437 - learning_rate: 0.0010
# Epoch 20/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1339 - mae: 0.2373 - val_loss: 0.1478 - val_mae: 0.2577 - learning_rate: 0.0010
# Epoch 21/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1315 - mae: 0.2360 - val_loss: 0.1753 - val_mae: 0.2749 - learning_rate: 0.0010
# Epoch 22/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1320 - mae: 0.2372 - val_loss: 0.1431 - val_mae: 0.2517 - learning_rate: 0.0010
# Epoch 23/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1315 - mae: 0.2351 - val_loss: 0.1448 - val_mae: 0.2645 - learning_rate: 0.0010
# Epoch 24/100
# 530/545 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1296 - mae: 0.2354
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1295 - mae: 0.2356 - val_loss: 0.1585 - val_mae: 0.2710 - learning_rate: 0.0010
# Epoch 25/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1173 - mae: 0.2251 - val_loss: 0.1561 - val_mae: 0.2716 - learning_rate: 5.0000e-04
# Epoch 26/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1105 - mae: 0.2230 - val_loss: 0.1274 - val_mae: 0.2429 - learning_rate: 5.0000e-04
# Epoch 27/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1103 - mae: 0.2235 - val_loss: 0.1283 - val_mae: 0.2430 - learning_rate: 5.0000e-04
# Epoch 28/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1095 - mae: 0.2224 - val_loss: 0.1356 - val_mae: 0.2557 - learning_rate: 5.0000e-04
# Epoch 29/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1101 - mae: 0.2239 - val_loss: 0.1206 - val_mae: 0.2290 - learning_rate: 5.0000e-04
# Epoch 30/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1097 - mae: 0.2226 - val_loss: 0.1088 - val_mae: 0.2215 - learning_rate: 5.0000e-04
# Epoch 31/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1096 - mae: 0.2225 - val_loss: 0.1044 - val_mae: 0.2205 - learning_rate: 5.0000e-04
# Epoch 32/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1087 - mae: 0.2219 - val_loss: 0.0994 - val_mae: 0.2143 - learning_rate: 5.0000e-04
# Epoch 33/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1091 - mae: 0.2220 - val_loss: 0.0998 - val_mae: 0.2112 - learning_rate: 5.0000e-04
# Epoch 34/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1088 - mae: 0.2218 - val_loss: 0.1005 - val_mae: 0.2117 - learning_rate: 5.0000e-04
# Epoch 35/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1102 - mae: 0.2231 - val_loss: 0.0997 - val_mae: 0.2141 - learning_rate: 5.0000e-04
# Epoch 36/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1090 - mae: 0.2209 - val_loss: 0.1161 - val_mae: 0.2270 - learning_rate: 5.0000e-04
# Epoch 37/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1060 - mae: 0.2193 - val_loss: 0.1164 - val_mae: 0.2313 - learning_rate: 5.0000e-04
# Epoch 38/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1053 - mae: 0.2197 - val_loss: 0.1047 - val_mae: 0.2190 - learning_rate: 5.0000e-04
# Epoch 39/100
# 532/545 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1115 - mae: 0.2250
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1092 - mae: 0.2227 - val_loss: 0.1100 - val_mae: 0.2231 - learning_rate: 5.0000e-04
# Epoch 40/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1004 - mae: 0.2140 - val_loss: 0.1030 - val_mae: 0.2167 - learning_rate: 2.5000e-04
# Epoch 41/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0969 - mae: 0.2125 - val_loss: 0.0966 - val_mae: 0.2115 - learning_rate: 2.5000e-04
# Epoch 42/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0955 - mae: 0.2124 - val_loss: 0.0969 - val_mae: 0.2156 - learning_rate: 2.5000e-04
# Epoch 43/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0950 - mae: 0.2118 - val_loss: 0.1063 - val_mae: 0.2232 - learning_rate: 2.5000e-04
# Epoch 44/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0943 - mae: 0.2116 - val_loss: 0.1103 - val_mae: 0.2303 - learning_rate: 2.5000e-04
# Epoch 45/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0946 - mae: 0.2121 - val_loss: 0.0818 - val_mae: 0.1969 - learning_rate: 2.5000e-04
# Epoch 46/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0931 - mae: 0.2106 - val_loss: 0.1079 - val_mae: 0.2297 - learning_rate: 2.5000e-04
# Epoch 47/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0942 - mae: 0.2127 - val_loss: 0.0744 - val_mae: 0.1865 - learning_rate: 2.5000e-04
# Epoch 48/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0926 - mae: 0.2107 - val_loss: 0.0904 - val_mae: 0.2060 - learning_rate: 2.5000e-04
# Epoch 49/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0940 - mae: 0.2108 - val_loss: 0.1067 - val_mae: 0.2239 - learning_rate: 2.5000e-04
# Epoch 50/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0914 - mae: 0.2093 - val_loss: 0.1087 - val_mae: 0.2316 - learning_rate: 2.5000e-04
# Epoch 51/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0919 - mae: 0.2098 - val_loss: 0.0955 - val_mae: 0.2145 - learning_rate: 2.5000e-04
# Epoch 52/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0925 - mae: 0.2100 - val_loss: 0.0937 - val_mae: 0.2101 - learning_rate: 2.5000e-04
# Epoch 53/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0923 - mae: 0.2097 - val_loss: 0.0866 - val_mae: 0.2013 - learning_rate: 2.5000e-04
# Epoch 54/100
# 538/545 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0915 - mae: 0.2077
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0912 - mae: 0.2084 - val_loss: 0.0993 - val_mae: 0.2163 - learning_rate: 2.5000e-04
# Epoch 55/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0883 - mae: 0.2057 - val_loss: 0.0911 - val_mae: 0.2070 - learning_rate: 1.2500e-04
# Epoch 56/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0865 - mae: 0.2035 - val_loss: 0.0903 - val_mae: 0.2074 - learning_rate: 1.2500e-04
# Epoch 57/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0855 - mae: 0.2033 - val_loss: 0.0816 - val_mae: 0.1977 - learning_rate: 1.2500e-04
# Epoch 58/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0858 - mae: 0.2044 - val_loss: 0.0989 - val_mae: 0.2161 - learning_rate: 1.2500e-04
# Epoch 59/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0839 - mae: 0.2018 - val_loss: 0.0791 - val_mae: 0.1952 - learning_rate: 1.2500e-04
# Epoch 60/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0842 - mae: 0.2020 - val_loss: 0.0827 - val_mae: 0.1996 - learning_rate: 1.2500e-04
# Epoch 61/100
# 541/545 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0832 - mae: 0.2021
# Epoch 61: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0831 - mae: 0.2017 - val_loss: 0.0943 - val_mae: 0.2135 - learning_rate: 1.2500e-04
# Epoch 62/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0813 - mae: 0.1995 - val_loss: 0.0843 - val_mae: 0.2019 - learning_rate: 6.2500e-05
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 47.
# 2026-02-16 13:46:29.996267: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:46:29.996421: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 13:46:30.419767: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_142', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-02-16 13:46:30.630405: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_142', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-02-16 13:46:31.162194: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_149', 100 bytes spill stores, 100 bytes spill loads
# 📊 Resultados CNN (Wavelet db2):
#   RMSE: 0.249267
#   MAE:  0.194726
#   R²:   0.938517
#   Tempo: 190.23s
# 'DL_Wavelet_CNN_2026-02-16T13-46-34.640259'

# %% [markdown]
# ## 5. Experimento 2: LSTM + Wavelet

# %%
print("="*70)
print("🔵 Experimento: LSTM com Wavelet db2")
print("="*70)

tf.keras.backend.clear_session()

# Criar modelo
lstm_params = DL_MODELS_CONFIG['LSTM']
model_lstm = create_lstm_model(input_shape, params=lstm_params)
model_lstm.summary()

# Callbacks
model_path = str(MODELS_DIR / "wavelet_lstm_best.keras")
callbacks = get_callbacks(model_path, patience_early=15, patience_lr=7)

# Treinar
t0 = time.time()
history_lstm = model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=training_config['epochs'],
    batch_size=training_config['batch_size'],
    callbacks=callbacks,
    verbose=1
)
elapsed = time.time() - t0

# Predições
y_pred_lstm = model_lstm.predict(X_test, verbose=0).flatten()

# Métricas
lstm_metrics = evaluator.evaluate(y_test, y_pred_lstm)

print(f"\n📊 Resultados LSTM (Wavelet db2):")
print(f"  RMSE: {lstm_metrics['rmse']:.6f}")
print(f"  MAE:  {lstm_metrics['mae']:.6f}")
print(f"  R²:   {lstm_metrics['r2']:.6f}")

all_results['Wavelet_LSTM'] = {
    'metrics': lstm_metrics,
    'time': elapsed,
    'epochs': len(history_lstm.history['loss']),
    'y_pred': y_pred_lstm,
    'params': model_lstm.count_params()
}
all_histories['Wavelet_LSTM'] = history_lstm.history

results_manager.log_experiment(
    'DL_Wavelet', 'LSTM', lstm_metrics,
    {'params': lstm_params, 'wavelet': WAVELET_CONFIG}
)
# Out:
# ======================================================================
# 🔵 Experimento: LSTM com Wavelet db2
# ======================================================================
# Model: "LSTM_Regressor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 129, 5)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 129, 128)       │        68,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,241 (477.50 KB)
#  Trainable params: 122,241 (477.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - loss: 0.4309 - mae: 0.4017 - val_loss: 0.2234 - val_mae: 0.3069 - learning_rate: 0.0010
# Epoch 2/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.3260 - mae: 0.3724 - val_loss: 0.1555 - val_mae: 0.2668 - learning_rate: 0.0010
# Epoch 3/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2941 - mae: 0.3585 - val_loss: 0.1126 - val_mae: 0.2295 - learning_rate: 0.0010
# Epoch 4/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2803 - mae: 0.3530 - val_loss: 0.1446 - val_mae: 0.2758 - learning_rate: 0.0010
# Epoch 5/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - loss: 0.2740 - mae: 0.3498 - val_loss: 0.1384 - val_mae: 0.2664 - learning_rate: 0.0010
# Epoch 6/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2637 - mae: 0.3414 - val_loss: 0.1354 - val_mae: 0.2657 - learning_rate: 0.0010
# Epoch 7/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2611 - mae: 0.3408 - val_loss: 0.1123 - val_mae: 0.2425 - learning_rate: 0.0010
# Epoch 8/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2513 - mae: 0.3346 - val_loss: 0.1139 - val_mae: 0.2465 - learning_rate: 0.0010
# Epoch 9/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2628 - mae: 0.3409 - val_loss: 0.1268 - val_mae: 0.2539 - learning_rate: 0.0010
# Epoch 10/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2519 - mae: 0.3339 - val_loss: 0.1174 - val_mae: 0.2488 - learning_rate: 0.0010
# Epoch 11/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2462 - mae: 0.3292 - val_loss: 0.1196 - val_mae: 0.2541 - learning_rate: 0.0010
# Epoch 12/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2468 - mae: 0.3312 - val_loss: 0.1326 - val_mae: 0.2626 - learning_rate: 0.0010
# Epoch 13/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2408 - mae: 0.3268 - val_loss: 0.1069 - val_mae: 0.2360 - learning_rate: 0.0010
# Epoch 14/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2430 - mae: 0.3267 - val_loss: 0.1031 - val_mae: 0.2309 - learning_rate: 0.0010
# Epoch 15/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2417 - mae: 0.3265 - val_loss: 0.1259 - val_mae: 0.2541 - learning_rate: 0.0010
# Epoch 16/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2373 - mae: 0.3230 - val_loss: 0.1333 - val_mae: 0.2659 - learning_rate: 0.0010
# Epoch 17/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2411 - mae: 0.3238 - val_loss: 0.0858 - val_mae: 0.2106 - learning_rate: 0.0010
# Epoch 18/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - loss: 0.2385 - mae: 0.3235 - val_loss: 0.1154 - val_mae: 0.2407 - learning_rate: 0.0010
# Epoch 19/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 0.2320 - mae: 0.3177 - val_loss: 0.1351 - val_mae: 0.2714 - learning_rate: 0.0010
# Epoch 20/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - loss: 0.2291 - mae: 0.3183 - val_loss: 0.0918 - val_mae: 0.2199 - learning_rate: 0.0010
# Epoch 21/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2282 - mae: 0.3170 - val_loss: 0.0985 - val_mae: 0.2250 - learning_rate: 0.0010
# Epoch 22/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2282 - mae: 0.3156 - val_loss: 0.1038 - val_mae: 0.2318 - learning_rate: 0.0010
# Epoch 23/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2235 - mae: 0.3137 - val_loss: 0.0977 - val_mae: 0.2279 - learning_rate: 0.0010
# Epoch 24/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2288 - mae: 0.3161
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2290 - mae: 0.3153 - val_loss: 0.1494 - val_mae: 0.2773 - learning_rate: 0.0010
# Epoch 25/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2139 - mae: 0.3029 - val_loss: 0.1222 - val_mae: 0.2487 - learning_rate: 5.0000e-04
# Epoch 26/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2106 - mae: 0.2998 - val_loss: 0.1204 - val_mae: 0.2507 - learning_rate: 5.0000e-04
# Epoch 27/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2067 - mae: 0.2979 - val_loss: 0.1091 - val_mae: 0.2376 - learning_rate: 5.0000e-04
# Epoch 28/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2075 - mae: 0.2979 - val_loss: 0.1355 - val_mae: 0.2644 - learning_rate: 5.0000e-04
# Epoch 29/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2122 - mae: 0.3008 - val_loss: 0.1116 - val_mae: 0.2398 - learning_rate: 5.0000e-04
# Epoch 30/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.2030 - mae: 0.2956 - val_loss: 0.1079 - val_mae: 0.2362 - learning_rate: 5.0000e-04
# Epoch 31/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2038 - mae: 0.2951
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2042 - mae: 0.2956 - val_loss: 0.1208 - val_mae: 0.2513 - learning_rate: 5.0000e-04
# Epoch 32/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.2031 - mae: 0.2927 - val_loss: 0.1132 - val_mae: 0.2402 - learning_rate: 2.5000e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
# 📊 Resultados LSTM (Wavelet db2):
#   RMSE: 0.327355
#   MAE:  0.247738
#   R²:   0.893960
# 'DL_Wavelet_LSTM_2026-02-16T13-54-17.191049'

# %% [markdown]
# ## 6. Experimento 3: CNN-LSTM + Wavelet

# %%
print("="*70)
print("🔵 Experimento: CNN-LSTM com Wavelet db2")
print("="*70)

tf.keras.backend.clear_session()

# Criar modelo
cnn_lstm_params = DL_MODELS_CONFIG['CNN_LSTM']
model_cnn_lstm = create_cnn_lstm_model(input_shape, params=cnn_lstm_params)
model_cnn_lstm.summary()

# Callbacks
model_path = str(MODELS_DIR / "wavelet_cnn_lstm_best.keras")
callbacks = get_callbacks(model_path, patience_early=15, patience_lr=7)

# Treinar
t0 = time.time()
history_cnn_lstm = model_cnn_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=training_config['epochs'],
    batch_size=training_config['batch_size'],
    callbacks=callbacks,
    verbose=1
)
elapsed = time.time() - t0

# Predições
y_pred_cnn_lstm = model_cnn_lstm.predict(X_test, verbose=0).flatten()

# Métricas
cnn_lstm_metrics = evaluator.evaluate(y_test, y_pred_cnn_lstm)

print(f"\n📊 Resultados CNN-LSTM (Wavelet db2):")
print(f"  RMSE: {cnn_lstm_metrics['rmse']:.6f}")
print(f"  MAE:  {cnn_lstm_metrics['mae']:.6f}")
print(f"  R²:   {cnn_lstm_metrics['r2']:.6f}")

all_results['Wavelet_CNN_LSTM'] = {
    'metrics': cnn_lstm_metrics,
    'time': elapsed,
    'epochs': len(history_cnn_lstm.history['loss']),
    'y_pred': y_pred_cnn_lstm,
    'params': model_cnn_lstm.count_params()
}
all_histories['Wavelet_CNN_LSTM'] = history_cnn_lstm.history

results_manager.log_experiment(
    'DL_Wavelet', 'CNN_LSTM', cnn_lstm_metrics,
    {'params': cnn_lstm_params, 'wavelet': WAVELET_CONFIG}
)
# Out:
# ======================================================================
# 🔵 Experimento: CNN-LSTM com Wavelet db2
# ======================================================================
# Model: "CNN_LSTM_Regressor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 129, 5)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 129, 64)        │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 129, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 64, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 32, 100)        │        91,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        30,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         3,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 152,265 (594.79 KB)
#  Trainable params: 151,881 (593.29 KB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - loss: 0.4620 - mae: 0.2986 - val_loss: 0.2399 - val_mae: 0.2066 - learning_rate: 0.0010
# Epoch 2/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.2087 - mae: 0.2364 - val_loss: 0.1281 - val_mae: 0.1852 - learning_rate: 0.0010
# Epoch 3/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.1365 - mae: 0.2204 - val_loss: 0.1015 - val_mae: 0.1933 - learning_rate: 0.0010
# Epoch 4/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.1098 - mae: 0.2122 - val_loss: 0.0802 - val_mae: 0.1776 - learning_rate: 0.0010
# Epoch 5/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0971 - mae: 0.2044 - val_loss: 0.0891 - val_mae: 0.1981 - learning_rate: 0.0010
# Epoch 6/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0944 - mae: 0.2037 - val_loss: 0.0704 - val_mae: 0.1727 - learning_rate: 0.0010
# Epoch 7/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0899 - mae: 0.2004 - val_loss: 0.0749 - val_mae: 0.1824 - learning_rate: 0.0010
# Epoch 8/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0875 - mae: 0.1978 - val_loss: 0.0663 - val_mae: 0.1707 - learning_rate: 0.0010
# Epoch 9/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0863 - mae: 0.1966 - val_loss: 0.0701 - val_mae: 0.1773 - learning_rate: 0.0010
# Epoch 10/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0852 - mae: 0.1948 - val_loss: 0.0663 - val_mae: 0.1710 - learning_rate: 0.0010
# Epoch 11/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0834 - mae: 0.1939 - val_loss: 0.0674 - val_mae: 0.1717 - learning_rate: 0.0010
# Epoch 12/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0845 - mae: 0.1949 - val_loss: 0.0632 - val_mae: 0.1635 - learning_rate: 0.0010
# Epoch 13/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0824 - mae: 0.1924 - val_loss: 0.0693 - val_mae: 0.1746 - learning_rate: 0.0010
# Epoch 14/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0805 - mae: 0.1898 - val_loss: 0.0699 - val_mae: 0.1781 - learning_rate: 0.0010
# Epoch 15/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - loss: 0.0806 - mae: 0.1905 - val_loss: 0.0689 - val_mae: 0.1765 - learning_rate: 0.0010
# Epoch 16/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0799 - mae: 0.1893 - val_loss: 0.0769 - val_mae: 0.1912 - learning_rate: 0.0010
# Epoch 17/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0803 - mae: 0.1904 - val_loss: 0.0645 - val_mae: 0.1665 - learning_rate: 0.0010
# Epoch 18/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0783 - mae: 0.1876 - val_loss: 0.0725 - val_mae: 0.1840 - learning_rate: 0.0010
# Epoch 19/100
# 544/545 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0785 - mae: 0.1869
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0786 - mae: 0.1872 - val_loss: 0.0727 - val_mae: 0.1831 - learning_rate: 0.0010
# Epoch 20/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0682 - mae: 0.1764 - val_loss: 0.0565 - val_mae: 0.1614 - learning_rate: 5.0000e-04
# Epoch 21/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - loss: 0.0654 - mae: 0.1743 - val_loss: 0.0588 - val_mae: 0.1668 - learning_rate: 5.0000e-04
# Epoch 22/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - loss: 0.0654 - mae: 0.1744 - val_loss: 0.0571 - val_mae: 0.1649 - learning_rate: 5.0000e-04
# Epoch 23/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0629 - mae: 0.1722 - val_loss: 0.0612 - val_mae: 0.1711 - learning_rate: 5.0000e-04
# Epoch 24/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0630 - mae: 0.1724 - val_loss: 0.0579 - val_mae: 0.1651 - learning_rate: 5.0000e-04
# Epoch 25/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0636 - mae: 0.1733 - val_loss: 0.0642 - val_mae: 0.1788 - learning_rate: 5.0000e-04
# Epoch 26/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0625 - mae: 0.1712 - val_loss: 0.0674 - val_mae: 0.1811 - learning_rate: 5.0000e-04
# Epoch 27/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0623 - mae: 0.1705 - val_loss: 0.0561 - val_mae: 0.1634 - learning_rate: 5.0000e-04
# Epoch 28/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0615 - mae: 0.1701 - val_loss: 0.0567 - val_mae: 0.1653 - learning_rate: 5.0000e-04
# Epoch 29/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0618 - mae: 0.1702 - val_loss: 0.0611 - val_mae: 0.1755 - learning_rate: 5.0000e-04
# Epoch 30/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0609 - mae: 0.1692 - val_loss: 0.0593 - val_mae: 0.1703 - learning_rate: 5.0000e-04
# Epoch 31/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0605 - mae: 0.1686 - val_loss: 0.0598 - val_mae: 0.1697 - learning_rate: 5.0000e-04
# Epoch 32/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0598 - mae: 0.1675 - val_loss: 0.0566 - val_mae: 0.1652 - learning_rate: 5.0000e-04
# Epoch 33/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0606 - mae: 0.1688 - val_loss: 0.0543 - val_mae: 0.1609 - learning_rate: 5.0000e-04
# Epoch 34/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0585 - mae: 0.1655 - val_loss: 0.0630 - val_mae: 0.1751 - learning_rate: 5.0000e-04
# Epoch 35/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0596 - mae: 0.1670 - val_loss: 0.0610 - val_mae: 0.1737 - learning_rate: 5.0000e-04
# Epoch 36/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0582 - mae: 0.1649 - val_loss: 0.0621 - val_mae: 0.1743 - learning_rate: 5.0000e-04
# Epoch 37/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0580 - mae: 0.1651 - val_loss: 0.0601 - val_mae: 0.1721 - learning_rate: 5.0000e-04
# Epoch 38/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0585 - mae: 0.1657 - val_loss: 0.0591 - val_mae: 0.1709 - learning_rate: 5.0000e-04
# Epoch 39/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0585 - mae: 0.1651 - val_loss: 0.0662 - val_mae: 0.1814 - learning_rate: 5.0000e-04
# Epoch 40/100
# 544/545 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0556 - mae: 0.1608
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0565 - mae: 0.1623 - val_loss: 0.0646 - val_mae: 0.1786 - learning_rate: 5.0000e-04
# Epoch 41/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0516 - mae: 0.1555 - val_loss: 0.0546 - val_mae: 0.1647 - learning_rate: 2.5000e-04
# Epoch 42/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0517 - mae: 0.1562 - val_loss: 0.0564 - val_mae: 0.1691 - learning_rate: 2.5000e-04
# Epoch 43/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - loss: 0.0501 - mae: 0.1543 - val_loss: 0.0569 - val_mae: 0.1704 - learning_rate: 2.5000e-04
# Epoch 44/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - loss: 0.0494 - mae: 0.1535 - val_loss: 0.0568 - val_mae: 0.1692 - learning_rate: 2.5000e-04
# Epoch 45/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0491 - mae: 0.1532 - val_loss: 0.0603 - val_mae: 0.1775 - learning_rate: 2.5000e-04
# Epoch 46/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0482 - mae: 0.1521 - val_loss: 0.0576 - val_mae: 0.1722 - learning_rate: 2.5000e-04
# Epoch 47/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0495 - mae: 0.1536
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0481 - mae: 0.1519 - val_loss: 0.0553 - val_mae: 0.1666 - learning_rate: 2.5000e-04
# Epoch 48/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0461 - mae: 0.1485 - val_loss: 0.0559 - val_mae: 0.1698 - learning_rate: 1.2500e-04
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 33.
#
# 📊 Resultados CNN-LSTM (Wavelet db2):
#   RMSE: 0.266868
#   MAE:  0.204470
#   R²:   0.929527
# 'DL_Wavelet_CNN_LSTM_2026-02-16T14-03-12.663094'

# %% [markdown]
# ## 7. Experimento 4: Transformer + Wavelet

# %%
print("="*70)
print("🔵 Experimento: Transformer com Wavelet db2")
print("="*70)

tf.keras.backend.clear_session()

# Criar modelo
transformer_params = DL_MODELS_CONFIG['Transformer']
model_transformer = create_transformer_model(input_shape, params=transformer_params)
model_transformer.summary()

# Callbacks
model_path = str(MODELS_DIR / "wavelet_transformer_best.keras")
callbacks = get_callbacks(model_path, patience_early=15, patience_lr=7)

# Treinar
t0 = time.time()
history_transformer = model_transformer.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=training_config['epochs'],
    batch_size=training_config['batch_size'],
    callbacks=callbacks,
    verbose=1
)
elapsed = time.time() - t0

# Predições
y_pred_transformer = model_transformer.predict(X_test, verbose=0).flatten()

# Métricas
transformer_metrics = evaluator.evaluate(y_test, y_pred_transformer)

print(f"\n📊 Resultados Transformer (Wavelet db2):")
print(f"  RMSE: {transformer_metrics['rmse']:.6f}")
print(f"  MAE:  {transformer_metrics['mae']:.6f}")
print(f"  R²:   {transformer_metrics['r2']:.6f}")

all_results['Wavelet_Transformer'] = {
    'metrics': transformer_metrics,
    'time': elapsed,
    'epochs': len(history_transformer.history['loss']),
    'y_pred': y_pred_transformer,
    'params': model_transformer.count_params()
}
all_histories['Wavelet_Transformer'] = history_transformer.history

results_manager.log_experiment(
    'DL_Wavelet', 'Transformer', transformer_metrics,
    {'params': transformer_params, 'wavelet': WAVELET_CONFIG}
)
# Out:
# ======================================================================
# 🔵 Experimento: Transformer com Wavelet db2
# ======================================================================
# Model: "Transformer_Regressor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 129, 5)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 129, 256)       │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 129, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_1             │ (None, 129, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 702,977 (2.68 MB)
#  Trainable params: 702,977 (2.68 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 2026-02-16 14:03:23.339229: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6366', 92 bytes spill stores, 92 bytes spill loads
#
# 2026-02-16 14:03:23.897205: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7038', 96 bytes spill stores, 96 bytes spill loads
#
# 2026-02-16 14:03:23.957765: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6671', 100 bytes spill stores, 100 bytes spill loads
#
# 2026-02-16 14:03:24.059027: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6913', 340 bytes spill stores, 340 bytes spill loads
#
# 2026-02-16 14:03:24.203142: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_57', 388 bytes spill stores, 356 bytes spill loads
#
# 2026-02-16 14:03:24.302711: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6878', 112 bytes spill stores, 112 bytes spill loads
#
# 2026-02-16 14:03:24.367287: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_50', 4 bytes spill stores, 8 bytes spill loads
#
# 2026-02-16 14:03:24.443492: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6996', 100 bytes spill stores, 100 bytes spill loads
#
# 2026-02-16 14:03:24.551132: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6392', 308 bytes spill stores, 308 bytes spill loads
#
# 2026-02-16 14:03:24.567301: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_56', 52 bytes spill stores, 52 bytes spill loads
# 537/545 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8652 - mae: 0.7276
# 2026-02-16 14:03:50.170313: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 14:03:50.170677: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 14:03:50.171781: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 14:03:50.171870: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-16 14:03:50.645279: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-02-16 14:03:50.711944: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_51', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-02-16 14:03:51.035232: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_53', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-02-16 14:03:51.196807: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6', 16 bytes spill stores, 16 bytes spill loads
#
# 2026-02-16 14:03:51.321277: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7038', 96 bytes spill stores, 96 bytes spill loads
#
# 2026-02-16 14:03:51.359756: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_31', 104 bytes spill stores, 104 bytes spill loads
#
# 2026-02-16 14:03:51.369875: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 84 bytes spill stores, 84 bytes spill loads
#
# 2026-02-16 14:03:51.393405: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6671', 100 bytes spill stores, 100 bytes spill loads
#
# 2026-02-16 14:03:51.636572: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_54', 4 bytes spill stores, 8 bytes spill loads
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.8648 - mae: 0.7274
# 2026-02-16 14:04:14.588554: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-02-16 14:04:14.701305: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-02-16 14:04:15.028420: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_19', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-02-16 14:04:15.232575: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_20', 4 bytes spill stores, 8 bytes spill loads
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 65s 65ms/step - loss: 0.8344 - mae: 0.7110 - val_loss: 0.8761 - val_mae: 0.7379 - learning_rate: 0.0010
# Epoch 2/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.7882 - mae: 0.6850 - val_loss: 0.8425 - val_mae: 0.7324 - learning_rate: 0.0010
# Epoch 3/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.7670 - mae: 0.6736 - val_loss: 0.8273 - val_mae: 0.7241 - learning_rate: 0.0010
# Epoch 4/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.7570 - mae: 0.6673 - val_loss: 0.7840 - val_mae: 0.7022 - learning_rate: 0.0010
# Epoch 5/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.7559 - mae: 0.6671 - val_loss: 0.9486 - val_mae: 0.7723 - learning_rate: 0.0010
# Epoch 6/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.7594 - mae: 0.6688 - val_loss: 0.7733 - val_mae: 0.6941 - learning_rate: 0.0010
# Epoch 7/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.8065 - mae: 0.6889 - val_loss: 0.8195 - val_mae: 0.7127 - learning_rate: 0.0010
# Epoch 8/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8594 - mae: 0.7207 - val_loss: 0.8952 - val_mae: 0.7444 - learning_rate: 0.0010
# Epoch 9/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.8847 - mae: 0.7313 - val_loss: 1.0879 - val_mae: 0.8137 - learning_rate: 0.0010
# Epoch 10/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.9655 - mae: 0.7735 - val_loss: 0.9111 - val_mae: 0.7592 - learning_rate: 0.0010
# Epoch 11/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8877 - mae: 0.7368 - val_loss: 0.8873 - val_mae: 0.7514 - learning_rate: 0.0010
# Epoch 12/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8654 - mae: 0.7286 - val_loss: 0.8893 - val_mae: 0.7545 - learning_rate: 0.0010
# Epoch 13/100
# 541/545 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8668 - mae: 0.7291
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8737 - mae: 0.7314 - val_loss: 0.8722 - val_mae: 0.7443 - learning_rate: 0.0010
# Epoch 14/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8526 - mae: 0.7224 - val_loss: 0.8590 - val_mae: 0.7406 - learning_rate: 5.0000e-04
# Epoch 15/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8509 - mae: 0.7202 - val_loss: 0.8696 - val_mae: 0.7405 - learning_rate: 5.0000e-04
# Epoch 16/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8520 - mae: 0.7197 - val_loss: 0.8680 - val_mae: 0.7448 - learning_rate: 5.0000e-04
# Epoch 17/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.8497 - mae: 0.7200 - val_loss: 0.8586 - val_mae: 0.7403 - learning_rate: 5.0000e-04
# Epoch 18/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.8446 - mae: 0.7183 - val_loss: 0.8698 - val_mae: 0.7417 - learning_rate: 5.0000e-04
# Epoch 19/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.8494 - mae: 0.7198 - val_loss: 0.8767 - val_mae: 0.7471 - learning_rate: 5.0000e-04
# Epoch 20/100
# 540/545 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8411 - mae: 0.7156
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.8480 - mae: 0.7193 - val_loss: 0.8693 - val_mae: 0.7456 - learning_rate: 5.0000e-04
# Epoch 21/100
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.8434 - mae: 0.7176 - val_loss: 0.8637 - val_mae: 0.7416 - learning_rate: 2.5000e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 2026-02-16 14:06:07.814642: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-02-16 14:06:08.166168: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_19', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-02-16 14:06:08.519491: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_20', 4 bytes spill stores, 8 bytes spill loads
#
# 2026-02-16 14:06:13.070504: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-02-16 14:06:13.151415: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-02-16 14:06:13.474547: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_19', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-02-16 14:06:13.619149: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_20', 4 bytes spill stores, 8 bytes spill loads
# 📊 Resultados Transformer (Wavelet db2):
#   RMSE: 0.950540
#   MAE:  0.765182
#   R²:   0.105935
# 'DL_Wavelet_Transformer_2026-02-16T14-06-16.571015'

# %% [markdown]
# ## 8. Comparação dos Resultados

# %%
# Criar DataFrame comparativo
comparison_data = []
for model_name, result in all_results.items():
    row = {
        'Model': model_name,
        'RMSE': result['metrics']['rmse'],
        'MAE': result['metrics']['mae'],
        'R²': result['metrics']['r2'],
        'Params': result['params'],
        'Time (s)': result['time'],
        'Epochs': result['epochs']
    }
    comparison_data.append(row)

comparison_df = pd.DataFrame(comparison_data)
comparison_df = comparison_df.sort_values('RMSE')

print("\n" + "="*70)
print("📊 COMPARAÇÃO FINAL - Deep Learning com Wavelet db2")
print("="*70)
print(comparison_df.to_string(index=False))

# Salvar
comparison_df.to_csv(RESULTS_DIR / "dl_wavelet_experiments" / "comparison_dl_wavelet.csv", index=False)
# Out:
# ======================================================================
# 📊 COMPARAÇÃO FINAL - Deep Learning com Wavelet db2
# ======================================================================
#               Model     RMSE      MAE       R²  Params   Time (s)  Epochs
#         Wavelet_CNN 0.249267 0.194726 0.938517  184961 190.232856      62
#    Wavelet_CNN_LSTM 0.266868 0.204470 0.929527  152265 533.008200      48
#        Wavelet_LSTM 0.327355 0.247738 0.893960  122241 459.414411      32
# Wavelet_Transformer 0.950540 0.765182 0.105935  702977 173.212758      21

# %%
# Visualização comparativa
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

metrics_to_plot = ['RMSE', 'MAE', 'R²']
colors = plt.cm.viridis(np.linspace(0.2, 0.8, len(comparison_df)))

for idx, metric in enumerate(metrics_to_plot):
    data = comparison_df.set_index('Model')[metric].sort_values(
        ascending=(metric != 'R²')
    )
    bars = axes[idx].barh(data.index, data.values, color=colors)
    axes[idx].set_xlabel(metric)
    axes[idx].set_title(f'Comparação: {metric}')
    axes[idx].grid(True, alpha=0.3, axis='x')
    
    for bar, val in zip(bars, data.values):
        axes[idx].text(val, bar.get_y() + bar.get_height()/2,
                      f'{val:.4f}', va='center', ha='left', fontsize=9)

plt.suptitle('Deep Learning com Wavelet db2', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(RESULTS_DIR / "dl_wavelet_experiments" / "comparison_dl_wavelet.png", dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 9. Resumo

# %%
# Encontrar melhor modelo
best_model_name = comparison_df.iloc[0]['Model']

print("\n" + "="*70)
print("📋 RESUMO - Experimentos DL com Wavelet db2")
print("="*70)
print(f"\n✅ Modelos avaliados: {len(all_results)}")
print(f"✅ Melhor modelo: {best_model_name}")
print(f"✅ Melhor RMSE: {comparison_df.iloc[0]['RMSE']:.6f}")
print(f"✅ Melhor R²: {comparison_df.iloc[0]['R²']:.6f}")
print(f"\n📁 Resultados salvos em: {RESULTS_DIR / 'dl_wavelet_experiments'}")
print("\n🎉 Notebook concluído com sucesso!")
# Out:
# ======================================================================
# 📋 RESUMO - Experimentos DL com Wavelet db2
# ======================================================================
#
# ✅ Modelos avaliados: 4
# ✅ Melhor modelo: Wavelet_CNN
# ✅ Melhor RMSE: 0.249267
# ✅ Melhor R²: 0.938517
#
# 📁 Resultados salvos em: /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/dl_wavelet_experiments
#
# 🎉 Notebook concluído com sucesso!
