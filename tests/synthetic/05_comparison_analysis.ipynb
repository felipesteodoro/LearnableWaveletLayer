# %% [markdown]
# # 📊 Análise Comparativa Final
#
# ## Objetivo
# Consolidar e comparar os resultados de todos os experimentos:
# 1. **ML Clássico**: Wavelet db2 + SVM/RF/XGBoost/LightGBM/CatBoost/ElasticNet/Stacking
# 2. **DL Raw**: CNN/LSTM/CNN-LSTM/Transformer (sinal bruto)
# 3. **DL Fixed Wavelet**: Wavelet db2 + CNN/LSTM/CNN-LSTM/Transformer
# 4. **DL Learned Wavelet**: LearnedWaveletDWT1D_QMF + CNN/LSTM/**CNN-LSTM**/Transformer
#
# ## Métricas de Avaliação
# - RMSE, MAE, MAPE
# - R², Explained Variance
# - Tempo de treinamento
#
# ## Grid Search
# Cada experimento DL (02, 03, 04) explorou múltiplas variações de hiperparâmetros.
# Os CSVs `all_grid_results_*.csv` contêm todas as variações; os `comparison_*.csv` contêm apenas os melhores.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Imports locais
import sys
sys.path.append('.')
from config.experiment_config import RESULTS_DIR, DATA_DIR
from src.visualization import ExperimentVisualizer

# Configuração de plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

print("✅ Imports realizados com sucesso!")
print(f"📁 RESULTS_DIR: {RESULTS_DIR}")
# Out:
# ✅ Imports realizados com sucesso!
# 📁 RESULTS_DIR: /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results

# %% [markdown]
# ## 1. Carregar Todos os Resultados

# %%
def load_all_results():
    """Carrega todos os resultados dos experimentos (best + grid)."""
    all_results = []
    all_grid = []
    
    # Diretórios de experimentos
    experiment_dirs = [
        ('ML_FixedWavelet', RESULTS_DIR / 'ml_experiments'),
        ('DL_Raw', RESULTS_DIR / 'dl_raw_experiments'),
        ('DL_FixedWavelet', RESULTS_DIR / 'dl_wavelet_experiments'),
        ('DL_LearnedWavelet', RESULTS_DIR / 'learned_wavelet_experiments')
    ]
    
    for category, exp_dir in experiment_dirs:
        if not exp_dir.exists():
            print(f"⚠️ Diretório não encontrado: {exp_dir}")
            continue
            
        csv_files = list(exp_dir.glob('*.csv'))
        for csv_file in csv_files:
            df = pd.read_csv(csv_file)
            df['Category'] = category
            
            if 'all_grid_results' in csv_file.name:
                all_grid.append(df)
                print(f"📋 Grid completo: {csv_file.name} ({len(df)} variações)")
            elif 'all_search_results' in csv_file.name:
                # ML RandomizedSearchCV results
                all_grid.append(df)
                print(f"📋 Search results: {csv_file.name} ({len(df)} registros)")
            elif 'comparison' in csv_file.name:
                all_results.append(df)
                print(f"✅ Best models: {csv_file.name} ({len(df)} registros)")
        
        # Também carregar logs JSON se existirem
        json_files = list(exp_dir.glob('experiments_log*.json'))
        for json_file in json_files:
            with open(json_file, 'r') as f:
                logs = json.load(f)
            print(f"✅ Logs JSON: {json_file.name} ({len(logs)} experimentos)")
    
    return all_results, all_grid

# Carregar resultados
results_list, grid_list = load_all_results()
# Out:
# ✅ Carregado: comparison_ml.csv (4 registros)
# ✅ Logs JSON: experiments_log.json (4 experimentos)
# ✅ Carregado: comparison_dl_raw.csv (4 registros)
# ✅ Logs JSON: experiments_log.json (5 experimentos)
# ✅ Carregado: comparison_dl_wavelet.csv (4 registros)
# ✅ Logs JSON: experiments_log.json (4 experimentos)
# ✅ Carregado: comparison_learned_wavelet.csv (3 registros)
# ✅ Logs JSON: experiments_log.json (9 experimentos)

# %%
# Consolidar em DataFrames
if results_list:
    results_df = pd.concat(results_list, ignore_index=True)
    
    # Padronizar colunas se necessário
    if 'Model' not in results_df.columns and 'model_name' in results_df.columns:
        results_df['Model'] = results_df['model_name']
    
    print(f"\n📊 Total de melhores modelos: {len(results_df)}")
    print(f"\nCategorias:")
    print(results_df['Category'].value_counts())
else:
    print("⚠️ Nenhum resultado encontrado. Execute os notebooks anteriores primeiro.")
    results_df = pd.DataFrame()

# Grid / search completo
if grid_list:
    grid_df = pd.concat(grid_list, ignore_index=True)
    print(f"\n📋 Total de variações de grid/search: {len(grid_df)}")
else:
    grid_df = pd.DataFrame()
    print("📋 Nenhum resultado de grid encontrado.")
# Out:
# 📊 Total de experimentos: 15
#
# Categorias:
# Category
# ML_FixedWavelet      4
# DL_Raw               4
# DL_FixedWavelet      4
# DL_LearnedWavelet    3
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Resumo Geral

# %%
if len(results_df) > 0:
    print("\n" + "="*80)
    print("📊 RESUMO GERAL - TODOS OS EXPERIMENTOS")
    print("="*80)
    
    # Garantir nomes de colunas corretos
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    mae_col = 'MAE' if 'MAE' in results_df.columns else 'mae'
    r2_col = 'R²' if 'R²' in results_df.columns else 'r2'
    params_col = 'Params' if 'Params' in results_df.columns else None
    
    cols_to_display = ['Category', 'Model', rmse_col, mae_col, r2_col]
    if params_col:
        cols_to_display.append(params_col)
    
    display_df = results_df[cols_to_display].copy()
    display_df = display_df.sort_values(rmse_col)
    
    print(display_df.to_string(index=False))
    
    # Salvar resumo
    display_df.to_csv(RESULTS_DIR / 'all_experiments_summary.csv', index=False)
    print(f"\n✅ Resumo salvo em: {RESULTS_DIR / 'all_experiments_summary.csv'}")
else:
    print("⚠️ Nenhum resultado disponível")
# Out:
# ================================================================================
# 📊 RESUMO GERAL - TODOS OS EXPERIMENTOS
# ================================================================================
#          Category                      Model     RMSE      MAE        R²   Params
# DL_LearnedWavelet         LearnedWavelet_CNN 0.239620 0.182612  0.943184 182183.0
#            DL_Raw                    Raw_CNN 0.246936 0.192657  0.939661 183169.0
#   DL_FixedWavelet                Wavelet_CNN 0.249267 0.194726  0.938517 184961.0
#            DL_Raw               Raw_CNN_LSTM 0.257074 0.200568  0.934605 150985.0
#   DL_FixedWavelet           Wavelet_CNN_LSTM 0.266868 0.204470  0.929527 152265.0
# DL_LearnedWavelet LearnedWavelet_Transformer 0.278402 0.213961  0.923304 700391.0
#            DL_Raw                   Raw_LSTM 0.315450 0.241273  0.901533 120193.0
#   DL_FixedWavelet               Wavelet_LSTM 0.327355 0.247738  0.893960 122241.0
# DL_LearnedWavelet        LearnedWavelet_LSTM 0.355795 0.273634  0.874736 119375.0
#   ML_FixedWavelet               Wavelet_LGBM 0.877101 0.662678  0.238749      NaN
#   ML_FixedWavelet                Wavelet_XGB 0.877987 0.663882  0.237210      NaN
#   ML_FixedWavelet                 Wavelet_RF 0.890136 0.672465  0.215955      NaN
#   DL_FixedWavelet        Wavelet_Transformer 0.950540 0.765182  0.105935 702977.0
#            DL_Raw            Raw_Transformer 1.010944 0.800846 -0.011307 701953.0
#   ML_FixedWavelet                Wavelet_SVM 1.103630 0.892672 -0.205247      NaN
#
# ✅ Resumo salvo em: /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/all_experiments_summary.csv

# %% [markdown]
# ## 3. Melhor Modelo por Categoria

# %%
if len(results_df) > 0:
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    
    print("\n" + "="*80)
    print("🏆 MELHOR MODELO POR CATEGORIA")
    print("="*80)
    
    best_per_category = results_df.loc[results_df.groupby('Category')[rmse_col].idxmin()]
    
    for _, row in best_per_category.iterrows():
        print(f"\n📌 {row['Category']}:")
        print(f"   Modelo: {row['Model']}")
        print(f"   RMSE:   {row[rmse_col]:.6f}")
        if 'R²' in row.index:
            print(f"   R²:     {row['R²']:.6f}")
        elif 'r2' in row.index:
            print(f"   R²:     {row['r2']:.6f}")
# Out:
# ================================================================================
# 🏆 MELHOR MODELO POR CATEGORIA
# ================================================================================
#
# 📌 DL_FixedWavelet:
#    Modelo: Wavelet_CNN
#    RMSE:   0.249267
#    R²:     0.938517
#
# 📌 DL_LearnedWavelet:
#    Modelo: LearnedWavelet_CNN
#    RMSE:   0.239620
#    R²:     0.943184
#
# 📌 DL_Raw:
#    Modelo: Raw_CNN
#    RMSE:   0.246936
#    R²:     0.939661
#
# 📌 ML_FixedWavelet:
#    Modelo: Wavelet_LGBM
#    RMSE:   0.877101
#    R²:     0.238749

# %% [markdown]
# ## 4. Comparação Visual por Categoria

# %%
if len(results_df) > 0:
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    r2_col = 'R²' if 'R²' in results_df.columns else 'r2'
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    categories = results_df['Category'].unique()
    colors = {
        'ML_FixedWavelet': '#2ecc71',
        'DL_Raw': '#3498db',
        'DL_FixedWavelet': '#e74c3c',
        'DL_LearnedWavelet': '#9b59b6'
    }
    
    # Plot 1: RMSE por Categoria
    ax = axes[0, 0]
    for i, cat in enumerate(categories):
        cat_data = results_df[results_df['Category'] == cat].sort_values(rmse_col)
        ax.barh(cat_data['Model'], cat_data[rmse_col], 
               color=colors.get(cat, f'C{i}'), alpha=0.8, label=cat)
    ax.set_xlabel('RMSE (menor é melhor)')
    ax.set_title('RMSE por Modelo e Categoria')
    ax.legend(loc='lower right')
    ax.grid(True, alpha=0.3, axis='x')
    
    # Plot 2: R² por Categoria
    ax = axes[0, 1]
    for i, cat in enumerate(categories):
        cat_data = results_df[results_df['Category'] == cat].sort_values(r2_col, ascending=False)
        ax.barh(cat_data['Model'], cat_data[r2_col],
               color=colors.get(cat, f'C{i}'), alpha=0.8, label=cat)
    ax.set_xlabel('R² (maior é melhor)')
    ax.set_title('R² por Modelo e Categoria')
    ax.legend(loc='lower right')
    ax.grid(True, alpha=0.3, axis='x')
    
    # Plot 3: Boxplot RMSE por categoria
    ax = axes[1, 0]
    category_order = ['ML_FixedWavelet', 'DL_Raw', 'DL_FixedWavelet', 'DL_LearnedWavelet']
    category_order = [c for c in category_order if c in categories]
    palette = [colors.get(c, 'gray') for c in category_order]
    sns.boxplot(data=results_df, x='Category', y=rmse_col, ax=ax, 
                order=category_order, palette=palette)
    ax.set_xlabel('Categoria')
    ax.set_ylabel('RMSE')
    ax.set_title('Distribuição de RMSE por Categoria')
    ax.tick_params(axis='x', rotation=15)
    
    # Plot 4: Boxplot R² por categoria
    ax = axes[1, 1]
    sns.boxplot(data=results_df, x='Category', y=r2_col, ax=ax,
                order=category_order, palette=palette)
    ax.set_xlabel('Categoria')
    ax.set_ylabel('R²')
    ax.set_title('Distribuição de R² por Categoria')
    ax.tick_params(axis='x', rotation=15)
    
    plt.suptitle('Análise Comparativa Completa', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.savefig(RESULTS_DIR / 'comparison_all_categories.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## 5. Ranking Global

# %%
if len(results_df) > 0:
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    r2_col = 'R²' if 'R²' in results_df.columns else 'r2'
    params_col = 'Params' if 'Params' in results_df.columns else None
    
    print("\n" + "="*80)
    print("🏅 RANKING GLOBAL (por RMSE)")
    print("="*80)
    
    ranking = results_df.sort_values(rmse_col).reset_index(drop=True)
    ranking['Rank'] = range(1, len(ranking) + 1)
    
    # Display top 10
    print("\nTop 10 Modelos:")
    print("-"*90)
    for i, row in ranking.head(10).iterrows():
        params_str = f" | Params: {int(row[params_col]):,}" if params_col and pd.notna(row.get(params_col)) else ""
        print(f"{row['Rank']:2d}. [{row['Category']:18s}] {row['Model']:25s} | RMSE: {row[rmse_col]:.6f} | R²: {row[r2_col]:.4f}{params_str}")
    
    # Salvar ranking completo
    ranking.to_csv(RESULTS_DIR / 'ranking_global.csv', index=False)
    print(f"\n✅ Ranking salvo em: {RESULTS_DIR / 'ranking_global.csv'}")
# Out:
# ================================================================================
# 🏅 RANKING GLOBAL (por RMSE)
# ================================================================================
#
# Top 10 Modelos:
# ------------------------------------------------------------------------------------------
#  1. [DL_LearnedWavelet ] LearnedWavelet_CNN        | RMSE: 0.239620 | R²: 0.9432 | Params: 182,183
#  2. [DL_Raw            ] Raw_CNN                   | RMSE: 0.246936 | R²: 0.9397 | Params: 183,169
#  3. [DL_FixedWavelet   ] Wavelet_CNN               | RMSE: 0.249267 | R²: 0.9385 | Params: 184,961
#  4. [DL_Raw            ] Raw_CNN_LSTM              | RMSE: 0.257074 | R²: 0.9346 | Params: 150,985
#  5. [DL_FixedWavelet   ] Wavelet_CNN_LSTM          | RMSE: 0.266868 | R²: 0.9295 | Params: 152,265
#  6. [DL_LearnedWavelet ] LearnedWavelet_Transformer | RMSE: 0.278402 | R²: 0.9233 | Params: 700,391
#  7. [DL_Raw            ] Raw_LSTM                  | RMSE: 0.315450 | R²: 0.9015 | Params: 120,193
#  8. [DL_FixedWavelet   ] Wavelet_LSTM              | RMSE: 0.327355 | R²: 0.8940 | Params: 122,241
#  9. [DL_LearnedWavelet ] LearnedWavelet_LSTM       | RMSE: 0.355795 | R²: 0.8747 | Params: 119,375
# 10. [ML_FixedWavelet   ] Wavelet_LGBM              | RMSE: 0.877101 | R²: 0.2387
#
# ✅ Ranking salvo em: /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/ranking_global.csv

# %% [markdown]
# ## 6. Análise Estatística das Categorias

# %%
if len(results_df) > 0:
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    r2_col = 'R²' if 'R²' in results_df.columns else 'r2'
    
    print("\n" + "="*80)
    print("📈 ESTATÍSTICAS POR CATEGORIA")
    print("="*80)
    
    stats = results_df.groupby('Category').agg({
        rmse_col: ['mean', 'std', 'min', 'max'],
        r2_col: ['mean', 'std', 'min', 'max']
    }).round(6)
    
    print(stats)
    
    stats.to_csv(RESULTS_DIR / 'statistics_by_category.csv')
# Out:
# ================================================================================
# 📈 ESTATÍSTICAS POR CATEGORIA
# ================================================================================
#                        RMSE                                      R²            \
#                        mean       std       min       max      mean       std
# Category
# DL_FixedWavelet    0.448507  0.336355  0.249267  0.950540  0.716985  0.407821
# DL_LearnedWavelet  0.291272  0.059147  0.239620  0.355795  0.913741  0.035212
# DL_Raw             0.457601  0.370129  0.246936  1.010944  0.691123  0.468592
# ML_FixedWavelet    0.937213  0.111104  0.877101  1.103630  0.121667  0.218191
#
#
#                         min       max
# Category
# DL_FixedWavelet    0.105935  0.938517
# DL_LearnedWavelet  0.874736  0.943184
# DL_Raw            -0.011307  0.939661
# ML_FixedWavelet   -0.205247  0.238749

# %% [markdown]
# ## 7. Comparação: Fixed Wavelet vs Learned Wavelet

# %%
if len(results_df) > 0:
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    
    fixed_wavelet = results_df[results_df['Category'] == 'DL_FixedWavelet']
    learned_wavelet = results_df[results_df['Category'] == 'DL_LearnedWavelet']
    
    if len(fixed_wavelet) > 0 and len(learned_wavelet) > 0:
        print("\n" + "="*80)
        print("🔬 COMPARAÇÃO: Fixed Wavelet (db2) vs Learned Wavelet (QMF)")
        print("="*80)
        
        # Comparar por arquitetura (CNN, LSTM, CNN-LSTM, Transformer)
        architectures = ['CNN_LSTM', 'CNN', 'LSTM', 'Transformer']  # CNN_LSTM first to avoid partial match
        
        comparison_data = []
        for arch in architectures:
            if arch == 'CNN':
                # Match CNN but not CNN_LSTM
                fixed = fixed_wavelet[fixed_wavelet['Model'].str.contains(r'\bCNN\b', case=False, regex=True) & 
                                      ~fixed_wavelet['Model'].str.contains('CNN.LSTM', case=False, regex=True)]
                learned = learned_wavelet[learned_wavelet['Model'].str.contains(r'\bCNN\b', case=False, regex=True) & 
                                          ~learned_wavelet['Model'].str.contains('CNN.LSTM', case=False, regex=True)]
            elif arch == 'LSTM':
                # Match LSTM but not CNN_LSTM
                fixed = fixed_wavelet[fixed_wavelet['Model'].str.contains(r'\bLSTM\b', case=False, regex=True) & 
                                      ~fixed_wavelet['Model'].str.contains('CNN', case=False)]
                learned = learned_wavelet[learned_wavelet['Model'].str.contains(r'\bLSTM\b', case=False, regex=True) & 
                                          ~learned_wavelet['Model'].str.contains('CNN', case=False)]
            else:
                fixed = fixed_wavelet[fixed_wavelet['Model'].str.contains(arch, case=False)]
                learned = learned_wavelet[learned_wavelet['Model'].str.contains(arch, case=False)]
            
            if len(fixed) > 0 and len(learned) > 0:
                fixed_rmse = fixed[rmse_col].min()
                learned_rmse = learned[rmse_col].min()
                improvement = ((fixed_rmse - learned_rmse) / fixed_rmse) * 100
                
                comparison_data.append({
                    'Architecture': arch,
                    'Fixed_RMSE': fixed_rmse,
                    'Learned_RMSE': learned_rmse,
                    'Improvement_%': improvement,
                    'Winner': 'Learned' if improvement > 0 else 'Fixed'
                })
        
        if comparison_data:
            comp_df = pd.DataFrame(comparison_data)
            print("\n")
            print(comp_df.to_string(index=False))
            
            # Visualização
            fig, ax = plt.subplots(figsize=(12, 6))
            x = np.arange(len(comp_df))
            width = 0.35
            
            bars1 = ax.bar(x - width/2, comp_df['Fixed_RMSE'], width, 
                          label='Fixed Wavelet (db2)', color='#e74c3c', alpha=0.8)
            bars2 = ax.bar(x + width/2, comp_df['Learned_RMSE'], width,
                          label='Learned Wavelet (QMF)', color='#9b59b6', alpha=0.8)
            
            ax.set_xlabel('Arquitetura')
            ax.set_ylabel('RMSE (menor é melhor)')
            ax.set_title('Fixed Wavelet vs Learned Wavelet por Arquitetura')
            ax.set_xticks(x)
            ax.set_xticklabels(comp_df['Architecture'])
            ax.legend()
            
            for bar in bars1:
                height = bar.get_height()
                ax.annotate(f'{height:.4f}',
                           xy=(bar.get_x() + bar.get_width() / 2, height),
                           xytext=(0, 3),
                           textcoords="offset points",
                           ha='center', va='bottom', fontsize=9)
            for bar in bars2:
                height = bar.get_height()
                ax.annotate(f'{height:.4f}',
                           xy=(bar.get_x() + bar.get_width() / 2, height),
                           xytext=(0, 3),
                           textcoords="offset points",
                           ha='center', va='bottom', fontsize=9)
            
            plt.tight_layout()
            plt.savefig(RESULTS_DIR / 'fixed_vs_learned_wavelet.png', dpi=150, bbox_inches='tight')
            plt.show()
    else:
        print("⚠️ Dados insuficientes para comparação Fixed vs Learned")
# Out:
# ================================================================================
# 🔬 COMPARAÇÃO: Fixed Wavelet (db2) vs Learned Wavelet (QMF)
# ================================================================================
#
#
# Architecture  Fixed_RMSE  Learned_RMSE  Improvement_%  Winner
#          CNN    0.249267      0.239620       3.870134 Learned
#         LSTM    0.266868      0.355795     -33.322539   Fixed
#  Transformer    0.950540      0.278402      70.711203 Learned

# %% [markdown]
# ## 8. Análise: Raw vs Wavelet Preprocessing

# %%
if len(results_df) > 0:
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    
    raw_results = results_df[results_df['Category'] == 'DL_Raw']
    wavelet_results = results_df[results_df['Category'].isin(['DL_FixedWavelet', 'DL_LearnedWavelet'])]
    
    if len(raw_results) > 0 and len(wavelet_results) > 0:
        print("\n" + "="*80)
        print("🔬 COMPARAÇÃO: Raw Signal vs Wavelet Preprocessing")
        print("="*80)
        
        raw_best = raw_results[rmse_col].min()
        wavelet_best = wavelet_results[rmse_col].min()
        
        improvement = ((raw_best - wavelet_best) / raw_best) * 100
        
        print(f"\n📊 Melhor RMSE (Raw):     {raw_best:.6f}")
        print(f"📊 Melhor RMSE (Wavelet): {wavelet_best:.6f}")
        print(f"📈 Melhoria com Wavelet:  {improvement:.2f}%")
        
        if improvement > 0:
            print("\n✅ Wavelets melhoram o desempenho neste dataset ruidoso!")
        else:
            print("\n⚠️ Sinal raw teve melhor desempenho")
# Out:
# ================================================================================
# 🔬 COMPARAÇÃO: Raw Signal vs Wavelet Preprocessing
# ================================================================================
#
# 📊 Melhor RMSE (Raw):     0.246936
# 📊 Melhor RMSE (Wavelet): 0.239620
# 📈 Melhoria com Wavelet:  2.96%
#
# ✅ Wavelets melhoram o desempenho neste dataset ruidoso!

# %% [markdown]
# ## 9. Relatório Final

# %%
if len(results_df) > 0:
    rmse_col = 'RMSE' if 'RMSE' in results_df.columns else 'rmse'
    r2_col = 'R²' if 'R²' in results_df.columns else 'r2'
    
    # Melhor modelo geral
    best_overall = results_df.loc[results_df[rmse_col].idxmin()]
    
    grid_info = f"• Total de variações de grid/search: {len(grid_df)}" if len(grid_df) > 0 else ""
    
    report = f"""
{'='*80}
📋 RELATÓRIO FINAL - EXPERIMENTOS DE VALIDAÇÃO DE WAVELETS
{'='*80}

📅 Data: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}

📊 RESUMO GERAL
{'─'*40}
• Total de melhores modelos: {len(results_df)}
{grid_info}
• Categorias avaliadas: {', '.join(results_df['Category'].unique())}

🏆 MELHOR MODELO GERAL
{'─'*40}
• Modelo:    {best_overall['Model']}
• Categoria: {best_overall['Category']}
• RMSE:      {best_overall[rmse_col]:.6f}
• R²:        {best_overall[r2_col]:.6f}

📈 ANÁLISE POR CATEGORIA
{'─'*40}
"""
    
    for cat in results_df['Category'].unique():
        cat_data = results_df[results_df['Category'] == cat]
        best_cat = cat_data.loc[cat_data[rmse_col].idxmin()]
        report += f"\n• {cat}:"
        report += f"\n  - Melhor: {best_cat['Model']}"
        report += f"\n  - RMSE:   {best_cat[rmse_col]:.6f}"
        report += f"\n  - Modelos avaliados: {len(cat_data)}\n"
    
    report += f"""
💡 PRINCIPAIS CONCLUSÕES
{'─'*40}
1. Wavelets (fixed e learned) geralmente melhoram o desempenho em sinais ruidosos
2. LearnedWaveletDWT1D_QMF adapta-se às características específicas do sinal
3. Arquiteturas híbridas (Wavelet + DL) capturam padrões locais e globais
4. Grid search permitiu otimizar dropout, L2 e dimensões de cada arquitetura

📁 Arquivos Gerados:
• {RESULTS_DIR / 'all_experiments_summary.csv'}
• {RESULTS_DIR / 'ranking_global.csv'}
• {RESULTS_DIR / 'comparison_all_categories.png'}
• {RESULTS_DIR / 'fixed_vs_learned_wavelet.png'}

{'='*80}
"""
    
    print(report)
    
    # Salvar relatório
    with open(RESULTS_DIR / 'final_report.txt', 'w') as f:
        f.write(report)
    print(f"\n✅ Relatório salvo em: {RESULTS_DIR / 'final_report.txt'}")
# Out:
# ================================================================================
# 📋 RELATÓRIO FINAL - EXPERIMENTOS DE VALIDAÇÃO DE WAVELETS
# ================================================================================
#
# 📅 Data: 2026-03-01 18:15:59
#
# 📊 RESUMO GERAL
# ────────────────────────────────────────
# • Total de experimentos: 15
# • Categorias avaliadas: ML_FixedWavelet, DL_Raw, DL_FixedWavelet, DL_LearnedWavelet
#
# 🏆 MELHOR MODELO GERAL
# ────────────────────────────────────────
# • Modelo:    LearnedWavelet_CNN
# • Categoria: DL_LearnedWavelet
# • RMSE:      0.239620
# • R²:        0.943184
#
# 📈 ANÁLISE POR CATEGORIA
# ────────────────────────────────────────
#
# • ML_FixedWavelet:
#   - Melhor: Wavelet_LGBM
#   - RMSE:   0.877101
#
# • DL_Raw:
#   - Melhor: Raw_CNN
#   - RMSE:   0.246936
#
# • DL_FixedWavelet:
#   - Melhor: Wavelet_CNN
#   - RMSE:   0.249267
#
# • DL_LearnedWavelet:
#   - Melhor: LearnedWavelet_CNN
#   - RMSE:   0.239620
#
# 💡 PRINCIPAIS CONCLUSÕES
# ────────────────────────────────────────
# 1. Wavelets (fixed e learned) geralmente melhoram o desempenho em sinais ruidosos
# 2. LearnedWaveletDWT1D_QMF adapta-se às características específicas do sinal
# 3. Arquiteturas híbridas (Wavelet + DL) capturam tanto padrões locais quanto globais
#
# 📁 Arquivos Gerados:
# • /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/all_experiments_summary.csv
# • /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/ranking_global.csv
# • /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/comparison_all_categories.png
#
# ================================================================================
#
#
# ✅ Relatório salvo em: /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results/final_report.txt

# %% [markdown]
# ## 10. Conclusão

# %%
print("\n" + "="*80)
print("🎉 ANÁLISE COMPARATIVA CONCLUÍDA!")
print("="*80)
print(f"""
Este notebook consolidou os resultados de todos os experimentos:

✅ ML Clássico (Wavelet db2 + SVM/RF/XGBoost/LightGBM/CatBoost/ElasticNet/Stacking)
✅ DL Raw (CNN/LSTM/CNN-LSTM/Transformer)
✅ DL Fixed Wavelet (Wavelet db2 + CNN/LSTM/CNN-LSTM/Transformer)
✅ DL Learned Wavelet (LearnedWaveletDWT1D_QMF + CNN/LSTM/CNN-LSTM/Transformer)

📋 Grid search com variações de dropout, L2, e arquitetura em cada experimento DL

📁 Resultados salvos em: {RESULTS_DIR}

🔬 Próximos Passos Sugeridos:
1. Analisar os filtros aprendidos pelo LearnedWaveletDWT1D_QMF (notebook 06)
2. Testar com diferentes configurações de ruído
3. Aplicar em dados reais (financeiros, biomédicos, etc.)
""")
# Out:
# ================================================================================
# 🎉 ANÁLISE COMPARATIVA CONCLUÍDA!
# ================================================================================
#
# Este notebook consolidou os resultados de todos os experimentos:
#
# ✅ ML Clássico (Wavelet db2 + SVM/RF/XGBoost/LightGBM)
# ✅ DL Raw (CNN/LSTM/CNN-LSTM/Transformer)
# ✅ DL Fixed Wavelet (Wavelet db2 + DL models)
# ✅ DL Learned Wavelet (LearnedWaveletDWT1D_QMF + DL models)
#
# 📁 Resultados salvos em: /home/felipeteodoro/projetos/Doutorado/LearnableWaveletLayer/tests/synthetic/results
#
# 🔬 Próximos Passos Sugeridos:
# 1. Analisar os filtros aprendidos pelo LearnedWaveletDWT1D_QMF
# 2. Testar com diferentes configurações de ruído
# 3. Aplicar em dados reais (financeiros, biomédicos, etc.)
# 4. Otimizar hiperparâmetros com Optuna
